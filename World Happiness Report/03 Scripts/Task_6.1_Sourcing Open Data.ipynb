# %% [markdown]
# # Importing Liabraries

# %%
import pandas as pd
import numpy as np 
import os

# %% [markdown]
# # Importing Dataset

# %%
path = r'C:\Users\swapn\World Happiness Report'

# %%
 Year_15 = pd.read_csv(r'C:\Users\swapn\World Happiness Report\02 Data\Original Data\2015.csv', index_col = False)

# %%
 Year_16 = pd.read_csv(r'C:\Users\swapn\World Happiness Report\02 Data\Original Data\2016.csv', index_col = False)

# %%
 Year_17 = pd.read_csv(r'C:\Users\swapn\World Happiness Report\02 Data\Original Data\2017.csv', index_col = False)

# %%
 Year_18 = pd.read_csv(r'C:\Users\swapn\World Happiness Report\02 Data\Original Data\2018.csv', index_col = False)

# %%
 Year_19 = pd.read_csv(r'C:\Users\swapn\World Happiness Report\02 Data\Original Data\2019.csv', index_col = False)

# %%
 Year_20 = pd.read_csv(r'C:\Users\swapn\World Happiness Report\02 Data\Original Data\2020.csv', index_col = False)

# %%
 Year_21 = pd.read_csv(r'C:\Users\swapn\World Happiness Report\02 Data\Original Data\2021.csv', index_col = False)

# %%
 Year_22 = pd.read_csv(r'C:\Users\swapn\World Happiness Report\02 Data\Original Data\2022.csv', index_col = False)

# %% [markdown]
# # Data Cleaning & wrangling of all Dataset

# %% [markdown]
#  1 Dataset of Year (2015)

# %%
Year_15.shape
# Out:
# (158, 12)

# %%
Year_15.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %%
Year_15.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# ...

# %%
#remove unnecessary columns
Year_15.drop(['Standard Error'], axis=1, inplace=True)

# %%
Year_15.head(5)
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.39651  1.34951                   0.94143  0.66557
# 1                   1.30232  1.40223                   0.94784  0.62877
# 2                   1.32548  1.36058                   0.87464  0.64938
# 3                   1.45900  1.33095                   0.88521  0.66973
# 4                   1.32629  1.32261                   0.90563  0.63297
#
#    Trust (Government Corruption)  Generosity  Dystopia Residual
# 0                        0.41978     0.29678            2.51738
# ...

# %%
# add new column
Year_15 ['Year'] = 2015

# %%
Year_15.head(5)
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.39651  1.34951                   0.94143  0.66557
# 1                   1.30232  1.40223                   0.94784  0.62877
# 2                   1.32548  1.36058                   0.87464  0.64938
# 3                   1.45900  1.33095                   0.88521  0.66973
# 4                   1.32629  1.32261                   0.90563  0.63297
#
#    Trust (Government Corruption)  Generosity  Dystopia Residual  Year
# 0                        0.41978     0.29678            2.51738  2015
# ...

# %%
Year_15.rename(columns = {'Happiness Rank':'Rank', 'Family':'Family (Social Support)', 'Freedom':'Freedom (Life Choices)', 'Generosity': 'Donations to Charity'}, inplace = True)

# %%
Year_15.head ()
# Out:
#        Country          Region  Rank  Happiness Score  \
# 0  Switzerland  Western Europe     1            7.587
# 1      Iceland  Western Europe     2            7.561
# 2      Denmark  Western Europe     3            7.527
# 3       Norway  Western Europe     4            7.522
# 4       Canada   North America     5            7.427
#
#    Economy (GDP per Capita)  Family (Social Support)  \
# 0                   1.39651                  1.34951
# 1                   1.30232                  1.40223
# 2                   1.32548                  1.36058
# 3                   1.45900                  1.33095
# 4                   1.32629                  1.32261
#
#    Health (Life Expectancy)  Freedom (Life Choices)  \
# 0                   0.94143                 0.66557
# 1                   0.94784                 0.62877
# 2                   0.87464                 0.64938
# 3                   0.88521                 0.66973
# ...

# %%
# checking the null value in data 
Year_15.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Rank                             0
# Happiness Score                  0
# Economy (GDP per Capita)         0
# Family (Social Support)          0
# Health (Life Expectancy)         0
# Freedom (Life Choices)           0
# Trust (Government Corruption)    0
# Donations to Charity             0
# Dystopia Residual                0
# Year                             0
# dtype: int64

# %%
# checking duplicates
Year_15[Year_15.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Country, Region, Rank, Happiness Score, Economy (GDP per Capita), Family (Social Support), Health (Life Expectancy), Freedom (Life Choices), Trust (Government Corruption), Donations to Charity, Dystopia Residual, Year]
# Index: []

# %%
Year_15_clean = Year_15.dropna()

# %%
Year_15_clean.shape
# Out:
# (158, 12)

# %%
Year_15_clean.describe()
# Out:
#              Rank  Happiness Score  Economy (GDP per Capita)  \
# count  158.000000       158.000000                158.000000
# mean    79.493671         5.375734                  0.846137
# std     45.754363         1.145010                  0.403121
# min      1.000000         2.839000                  0.000000
# 25%     40.250000         4.526000                  0.545808
# 50%     79.500000         5.232500                  0.910245
# 75%    118.750000         6.243750                  1.158448
# max    158.000000         7.587000                  1.690420
#
#        Family (Social Support)  Health (Life Expectancy)  \
# count               158.000000                158.000000
# mean                  0.991046                  0.630259
# std                   0.272369                  0.247078
# min                   0.000000                  0.000000
# 25%                   0.856823                  0.439185
# 50%                   1.029510                  0.696705
# ...

# %%
Year_15_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Rank                           158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Economy (GDP per Capita)       158 non-null    float64
#  5   Family (Social Support)        158 non-null    float64
#  6   Health (Life Expectancy)       158 non-null    float64
#  7   Freedom (Life Choices)         158 non-null    float64
#  8   Trust (Government Corruption)  158 non-null    float64
#  9   Donations to Charity           158 non-null    float64
#  10  Dystopia Residual              158 non-null    float64
#  11  Year                           158 non-null    int64
# ...

# %%
Year_15_clean = Year_15_clean[['Rank', 'Year', 'Country', 'Region', 'Happiness Score', 'Economy (GDP per Capita)', 'Family (Social Support)', 'Health (Life Expectancy)', 'Freedom (Life Choices)', 'Trust (Government Corruption)', 'Donations to Charity', 'Dystopia Residual']]

# %%
Year_15_clean.drop(['Dystopia Residual'], axis=1, inplace=True)

# %%
Year_15_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 11 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Rank                           158 non-null    int64
#  1   Year                           158 non-null    int64
#  2   Country                        158 non-null    object
#  3   Region                         158 non-null    object
#  4   Happiness Score                158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family (Social Support)        158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom (Life Choices)         158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Donations to Charity           158 non-null    float64
# dtypes: float64(7), int64(2), object(2)
# memory usage: 13.7+ KB

# %% [markdown]
#  2 Dataset of Year (2016)

# %%
Year_16.shape
# Out:
# (157, 13)

# %%
Year_16.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157 entries, 0 to 156
# Data columns (total 13 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        157 non-null    object
#  1   Region                         157 non-null    object
#  2   Happiness Rank                 157 non-null    int64
#  3   Happiness Score                157 non-null    float64
#  4   Lower Confidence Interval      157 non-null    float64
#  5   Upper Confidence Interval      157 non-null    float64
#  6   Economy (GDP per Capita)       157 non-null    float64
#  7   Family                         157 non-null    float64
#  8   Health (Life Expectancy)       157 non-null    float64
#  9   Freedom                        157 non-null    float64
#  10  Trust (Government Corruption)  157 non-null    float64
#  11  Generosity                     157 non-null    float64
# ...

# %%
Year_16.describe()
# Out:
#        Happiness Rank  Happiness Score  Lower Confidence Interval  \
# count      157.000000       157.000000                 157.000000
# mean        78.980892         5.382185                   5.282395
# std         45.466030         1.141674                   1.148043
# min          1.000000         2.905000                   2.732000
# 25%         40.000000         4.404000                   4.327000
# 50%         79.000000         5.314000                   5.237000
# 75%        118.000000         6.269000                   6.154000
# max        157.000000         7.526000                   7.460000
#
#        Upper Confidence Interval  Economy (GDP per Capita)      Family  \
# count                 157.000000                157.000000  157.000000
# mean                    5.481975                  0.953880    0.793621
# std                     1.136493                  0.412595    0.266706
# min                     3.078000                  0.000000    0.000000
# ...

# %%
Year_16.drop(['Lower Confidence Interval', 'Upper Confidence Interval'], axis=1, inplace=True)

# %%
Year_16.head ()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0      Denmark  Western Europe               1            7.526
# 1  Switzerland  Western Europe               2            7.509
# 2      Iceland  Western Europe               3            7.501
# 3       Norway  Western Europe               4            7.498
# 4      Finland  Western Europe               5            7.413
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.44178  1.16374                   0.79504  0.57941
# 1                   1.52733  1.14524                   0.86303  0.58557
# 2                   1.42666  1.18326                   0.86733  0.56624
# 3                   1.57744  1.12690                   0.79579  0.59609
# 4                   1.40598  1.13464                   0.81091  0.57104
#
#    Trust (Government Corruption)  Generosity  Dystopia Residual
# 0                        0.44453     0.36171            2.73939
# ...

# %%
Year_16.rename(columns = {'Happiness Rank':'Rank', 'Family':'Family (Social Support)', 'Freedom':'Freedom (Life Choices)', 'Generosity': 'Donations to Charity'}, inplace = True)

# %%
# checking the null value in data 
Year_16.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Rank                             0
# Happiness Score                  0
# Economy (GDP per Capita)         0
# Family (Social Support)          0
# Health (Life Expectancy)         0
# Freedom (Life Choices)           0
# Trust (Government Corruption)    0
# Donations to Charity             0
# Dystopia Residual                0
# dtype: int64

# %%
# checking duplicates
Year_16[Year_16.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Country, Region, Rank, Happiness Score, Economy (GDP per Capita), Family (Social Support), Health (Life Expectancy), Freedom (Life Choices), Trust (Government Corruption), Donations to Charity, Dystopia Residual]
# Index: []

# %%
# Add new column
Year_16 ['Year'] = 2016

# %%
Year_16
# Out:
#          Country                           Region  Rank  Happiness Score  \
# 0        Denmark                   Western Europe     1            7.526
# 1    Switzerland                   Western Europe     2            7.509
# 2        Iceland                   Western Europe     3            7.501
# 3         Norway                   Western Europe     4            7.498
# 4        Finland                   Western Europe     5            7.413
# ..           ...                              ...   ...              ...
# 152        Benin               Sub-Saharan Africa   153            3.484
# 153  Afghanistan                    Southern Asia   154            3.360
# 154         Togo               Sub-Saharan Africa   155            3.303
# 155        Syria  Middle East and Northern Africa   156            3.069
# 156      Burundi               Sub-Saharan Africa   157            2.905
#
#      Economy (GDP per Capita)  Family (Social Support)  \
# ...

# %%
# Change the order of the columns
Year_16 = Year_16[['Rank', 'Year', 'Country', 'Region', 'Happiness Score', 'Economy (GDP per Capita)', 'Family (Social Support)', 'Health (Life Expectancy)', 'Freedom (Life Choices)', 'Trust (Government Corruption)', 'Donations to Charity', 'Dystopia Residual']]

# %%
Year_16.head(5)
# Out:
#    Rank  Year      Country          Region  Happiness Score  \
# 0     1  2016      Denmark  Western Europe            7.526
# 1     2  2016  Switzerland  Western Europe            7.509
# 2     3  2016      Iceland  Western Europe            7.501
# 3     4  2016       Norway  Western Europe            7.498
# 4     5  2016      Finland  Western Europe            7.413
#
#    Economy (GDP per Capita)  Family (Social Support)  \
# 0                   1.44178                  1.16374
# 1                   1.52733                  1.14524
# 2                   1.42666                  1.18326
# 3                   1.57744                  1.12690
# 4                   1.40598                  1.13464
#
#    Health (Life Expectancy)  Freedom (Life Choices)  \
# 0                   0.79504                 0.57941
# 1                   0.86303                 0.58557
# 2                   0.86733                 0.56624
# 3                   0.79579                 0.59609
# ...

# %%
# drop the other missing values
Year_16_clean = Year_16.dropna()

# %%
Year_16_clean.shape
# Out:
# (157, 12)

# %%
Year_16_clean.head()
# Out:
#    Rank  Year      Country          Region  Happiness Score  \
# 0     1  2016      Denmark  Western Europe            7.526
# 1     2  2016  Switzerland  Western Europe            7.509
# 2     3  2016      Iceland  Western Europe            7.501
# 3     4  2016       Norway  Western Europe            7.498
# 4     5  2016      Finland  Western Europe            7.413
#
#    Economy (GDP per Capita)  Family (Social Support)  \
# 0                   1.44178                  1.16374
# 1                   1.52733                  1.14524
# 2                   1.42666                  1.18326
# 3                   1.57744                  1.12690
# 4                   1.40598                  1.13464
#
#    Health (Life Expectancy)  Freedom (Life Choices)  \
# 0                   0.79504                 0.57941
# 1                   0.86303                 0.58557
# 2                   0.86733                 0.56624
# 3                   0.79579                 0.59609
# ...

# %%
# dropping unnecessary column 
Year_16_clean.drop(['Dystopia Residual'], axis=1, inplace=True)

# %%
Year_16_clean.describe()
# Out:
#              Rank    Year  Happiness Score  Economy (GDP per Capita)  \
# count  157.000000   157.0       157.000000                157.000000
# mean    78.980892  2016.0         5.382185                  0.953880
# std     45.466030     0.0         1.141674                  0.412595
# min      1.000000  2016.0         2.905000                  0.000000
# 25%     40.000000  2016.0         4.404000                  0.670240
# 50%     79.000000  2016.0         5.314000                  1.027800
# 75%    118.000000  2016.0         6.269000                  1.279640
# max    157.000000  2016.0         7.526000                  1.824270
#
#        Family (Social Support)  Health (Life Expectancy)  \
# count               157.000000                157.000000
# mean                  0.793621                  0.557619
# std                   0.266706                  0.229349
# min                   0.000000                  0.000000
# ...

# %% [markdown]
#  3. Dataset of Year (2017)

# %%
Year_17.shape
# Out:
# (155, 12)

# %%
Year_17.describe()
# Out:
#        Happiness.Rank  Happiness.Score  Whisker.high  Whisker.low  \
# count      155.000000       155.000000    155.000000   155.000000
# mean        78.000000         5.354019      5.452326     5.255713
# std         44.888751         1.131230      1.118542     1.145030
# min          1.000000         2.693000      2.864884     2.521116
# 25%         39.500000         4.505500      4.608172     4.374955
# 50%         78.000000         5.279000      5.370032     5.193152
# 75%        116.500000         6.101500      6.194600     6.006527
# max        155.000000         7.537000      7.622030     7.479556
#
#        Economy..GDP.per.Capita.      Family  Health..Life.Expectancy.  \
# count                155.000000  155.000000                155.000000
# mean                   0.984718    1.188898                  0.551341
# std                    0.420793    0.287263                  0.237073
# min                    0.000000    0.000000                  0.000000
# ...

# %%
Year_17.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 155 entries, 0 to 154
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        155 non-null    object
#  1   Happiness.Rank                 155 non-null    int64
#  2   Happiness.Score                155 non-null    float64
#  3   Whisker.high                   155 non-null    float64
#  4   Whisker.low                    155 non-null    float64
#  5   Economy..GDP.per.Capita.       155 non-null    float64
#  6   Family                         155 non-null    float64
#  7   Health..Life.Expectancy.       155 non-null    float64
#  8   Freedom                        155 non-null    float64
#  9   Generosity                     155 non-null    float64
#  10  Trust..Government.Corruption.  155 non-null    float64
#  11  Dystopia.Residual              155 non-null    float64
# ...

# %%
#remove unnecessary columns
Year_17.drop(['Whisker.high', 'Whisker.low'], axis=1, inplace=True)

# %%
# add new column
Year_17 ['Year'] = 2017

# %%
Year_17.describe()
# Out:
#        Happiness.Rank  Happiness.Score  Economy..GDP.per.Capita.      Family  \
# count      155.000000       155.000000                155.000000  155.000000
# mean        78.000000         5.354019                  0.984718    1.188898
# std         44.888751         1.131230                  0.420793    0.287263
# min          1.000000         2.693000                  0.000000    0.000000
# 25%         39.500000         4.505500                  0.663371    1.042635
# 50%         78.000000         5.279000                  1.064578    1.253918
# 75%        116.500000         6.101500                  1.318027    1.414316
# max        155.000000         7.537000                  1.870766    1.610574
#
#        Health..Life.Expectancy.     Freedom  Generosity  \
# count                155.000000  155.000000  155.000000
# mean                   0.551341    0.408786    0.246883
# std                    0.237073    0.149997    0.134780
# ...

# %%
# Remane the columns

# %%
Year_17.rename(columns = {'Happiness.Rank':'Rank', 'Happiness.Score':'Happiness Score', 'Economy..GDP.per.Capita.':'Economy (GDP per Capita)', 'Family':'Family (Social Support)', 'Health..Life.Expectancy.':'Health (Life Expectancy)','Freedom':'Freedom (Life Choices)', 'Generosity': 'Donations to Charity', 'Trust..Government.Corruption.':'Trust (Government Corruption)'}, inplace = True)

# %%
# Correcting country name 
Year_17['Country'] = Year_17['Country'].replace('South Sudan', 'Sudan')

# %%
Year_17['Country'] = Year_17['Country'].replace('Taiwan Province of China', 'Taiwan')

# %%
Year_17['Country'] = Year_17['Country'].replace('Hong Kong S.A.R., China', 'Hong Kong')

# %%
# derive Region according to country names using loc()
Year_17.loc[Year_17['Country'].isin(['Australia', 'New Zealand']), 'Region'] = 'Australia and New Zealand'

# %%
Year_17.loc[Year_17['Country'].isin(['Albania', 'Armenia', 'Azerbaijan', 'Belarus', 'Bosnia and Herzegovina', 'Bulgaria', 'Croatia', 'Czech Republic', 'Estonia', 'Georgia', 'Hungary', 'Kazakhstan', 'Kosovo', 'Kyrgyzstan', 'Latvia', 'Lithuania', 'Macedonia', 'Moldova', 'Montenegro', 'Poland','Romania', 'Russia', 'Serbia', 'Slovakia', 'Slovenia', 'Tajikistan', 'Turkmenistan', 'Ukraine', 'Uzbekistan']), 'Region'] = 'Central and Eastern Europe'

# %%
Year_17.loc[Year_17['Country'].isin(['China', 'Hong Kong', 'Japan', 'Mongolia', 'South Korea', 'Taiwan']), 'Region'] = 'Eastern Asia'

# %%
Year_17.loc[Year_17['Country'].isin(['Argentina', 'Bolivia', 'Brazil', 'Chile', 'Colombia', 'Costa Rica', 'Dominican Republic','Ecuador', 'El Salvador', 'Guatemala', 'Haiti', 'Honduras', 'Jamaica', 'Mexico', 'Nicaragua', 'Panama', 'Paraguay', 'Peru', 'Suriname', 'Trinidad and Tobago', 'Uruguay', 'Uruguay']), 'Region'] = 'Latin America and Caribbean'

# %%
Year_17.loc[Year_17['Country'].isin(['Algeria', 'Bahrain','Egypt','Iran', 'Iraq', 'Israel', 'Jordan', 'Kuwait', 'Lebanon', 'Libya', 'Morocco', 'Oman', 'Palestinian Territories', 'Qatar', 'Saudi Arabia', 'Syria', 'Tunisia', 'Turkey', 'United Arab Emirates', 'Yemen']), 'Region'] = 'Middle East and Northern Africa'

# %%
Year_17.loc[Year_17['Country'].isin(['Canada', 'United States']), 'Region'] = 'North America'

# %%
Year_17.loc[Year_17['Country'].isin(['Cambodia', 'Indonesia', 'Laos', 'Malaysia', 'Myanmar', 'Philippines', 'Singapore', 'Thailand', 'Vietnam']), 'Region'] = 'Southeastern Asia'

# %%
Year_17.loc[Year_17['Country'].isin(['Afghanistan', 'Bangladesh', 'Bhutan', 'India', 'Nepal', 'Pakistan', 'Sri Lanka']), 'Region'] = 'Southern Asia'

# %%
Year_17.loc[Year_17['Country'].isin(['Angola', 'Benin', 'Botswana', 'Burkina Faso', 'Burundi', 'Cameroon', 'Central African Republic', 'Chad', 'Comoros', 'Congo (Brazzaville)', 'Congo (Kinshasa)', 'Djibouti', 'Ethiopia', 'Gabon', 'Ghana', 'Guinea', 'Ivory Coast', 'Kenya', 'Lesotho', 'Liberia', 'Madagascar', 'Malawi', 'Mali', 'Mauritania', 'Mauritius', 'Mozambique', 'Niger', 'Nigeria', 'Rwanda', 'Senegal', 'Sierra Leone', 'Somaliland region', 'South Africa', 'Sudan', 'Swaziland', 'Tanzania', 'Togo', 'Uganda', 'Zambia', 'Zimbabwe']), 'Region'] = 'Sub-Saharan Africa'

# %%
Year_17.loc[Year_17['Country'].isin(['Austria', 'Belgium', 'Cyprus', 'Denmark', 'Finland', 'France', 'Germany', 'Greece', 'Iceland', 'Ireland', 'Italy', 'Luxembourg', 'Malta', 'Netherlands', 'North Cyprus', 'Norway', 'Portugal', 'Spain', 'Sweden', 'Switzerland', 'United Kingdom']), 'Region'] = 'Western Europe'

# %%
Year_17.head(5)
# Out:
#        Country  Rank  Happiness Score  Economy (GDP per Capita)  \
# 0       Norway     1            7.537                  1.616463
# 1      Denmark     2            7.522                  1.482383
# 2      Iceland     3            7.504                  1.480633
# 3  Switzerland     4            7.494                  1.564980
# 4      Finland     5            7.469                  1.443572
#
#    Family (Social Support)  Health (Life Expectancy)  Freedom (Life Choices)  \
# 0                 1.533524                  0.796667                0.635423
# 1                 1.551122                  0.792566                0.626007
# 2                 1.610574                  0.833552                0.627163
# 3                 1.516912                  0.858131                0.620071
# 4                 1.540247                  0.809158                0.617951
#
#    Donations to Charity  Trust (Government Corruption)  Dystopia.Residual  \
# ...

# %%
Year_17.rename(columns = {'Dystopia.Residual': 'Dystopia Residual'}, inplace = True)

# %%
Year_17 = Year_17[['Rank', 'Year', 'Country', 'Region', 'Happiness Score', 'Economy (GDP per Capita)', 'Family (Social Support)', 'Health (Life Expectancy)', 'Freedom (Life Choices)', 'Trust (Government Corruption)', 'Donations to Charity', 'Dystopia Residual']]

# %%
Year_17.head()
# Out:
#    Rank  Year      Country          Region  Happiness Score  \
# 0     1  2017       Norway  Western Europe            7.537
# 1     2  2017      Denmark  Western Europe            7.522
# 2     3  2017      Iceland  Western Europe            7.504
# 3     4  2017  Switzerland  Western Europe            7.494
# 4     5  2017      Finland  Western Europe            7.469
#
#    Economy (GDP per Capita)  Family (Social Support)  \
# 0                  1.616463                 1.533524
# 1                  1.482383                 1.551122
# 2                  1.480633                 1.610574
# 3                  1.564980                 1.516912
# 4                  1.443572                 1.540247
#
#    Health (Life Expectancy)  Freedom (Life Choices)  \
# 0                  0.796667                0.635423
# 1                  0.792566                0.626007
# 2                  0.833552                0.627163
# 3                  0.858131                0.620071
# ...

# %%
# checking the null data
Year_17.isnull().sum()
# Out:
# Rank                             0
# Year                             0
# Country                          0
# Region                           4
# Happiness Score                  0
# Economy (GDP per Capita)         0
# Family (Social Support)          0
# Health (Life Expectancy)         0
# Freedom (Life Choices)           0
# Trust (Government Corruption)    0
# Donations to Charity             0
# Dystopia Residual                0
# dtype: int64

# %%
print("Missing Data:\n", Year_17[Year_17.isnull().any(axis=1)])
# Out:
# Missing Data:
#       Rank  Year    Country Region  Happiness Score  Economy (GDP per Capita)  \
# 49     50  2017     Belize    NaN            5.956                  0.907975
# 81     82  2017  Venezuela    NaN            5.250                  1.128431
# 92     93  2017    Somalia    NaN            5.151                  0.022643
# 110   111  2017    Namibia    NaN            4.574                  0.964434
#
#      Family (Social Support)  Health (Life Expectancy)  \
# 49                  1.081418                  0.450192
# 81                  1.431338                  0.617144
# 92                  0.721151                  0.113989
# 110                 1.098471                  0.338612
#
#      Freedom (Life Choices)  Trust (Government Corruption)  \
# 49                 0.547509                       0.096581
# 81                 0.153997                       0.064491
# 92                 0.602127                       0.282410
# ...

# %%
# Correcting missing data
Year_17.loc[Year_17['Country'].isin(['Belize', 'Venezuela']), 'Region'] = 'Latin America and Caribbean'

# %%
Year_17.loc[Year_17['Country'].isin(['Somalia', 'Namibia']), 'Region'] = 'Sub-Saharan Africa'

# %%
# checking the null data
Year_17.isnull().sum()
# Out:
# Rank                             0
# Year                             0
# Country                          0
# Region                           0
# Happiness Score                  0
# Economy (GDP per Capita)         0
# Family (Social Support)          0
# Health (Life Expectancy)         0
# Freedom (Life Choices)           0
# Trust (Government Corruption)    0
# Donations to Charity             0
# Dystopia Residual                0
# dtype: int64

# %%
# check for duplicates
Year_17[Year_17.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Rank, Year, Country, Region, Happiness Score, Economy (GDP per Capita), Family (Social Support), Health (Life Expectancy), Freedom (Life Choices), Trust (Government Corruption), Donations to Charity, Dystopia Residual]
# Index: []

# %%
# drop the missing values
Year_17_clean = Year_17.dropna()

# %%
# dropping unnecessary column 
Year_17_clean.drop(['Dystopia Residual'], axis=1, inplace=True)

# %%
Year_17_clean.shape
# Out:
# (155, 11)

# %%
Year_17_clean.describe()
# Out:
#              Rank    Year  Happiness Score  Economy (GDP per Capita)  \
# count  155.000000   155.0       155.000000                155.000000
# mean    78.000000  2017.0         5.354019                  0.984718
# std     44.888751     0.0         1.131230                  0.420793
# min      1.000000  2017.0         2.693000                  0.000000
# 25%     39.500000  2017.0         4.505500                  0.663371
# 50%     78.000000  2017.0         5.279000                  1.064578
# 75%    116.500000  2017.0         6.101500                  1.318027
# max    155.000000  2017.0         7.537000                  1.870766
#
#        Family (Social Support)  Health (Life Expectancy)  \
# count               155.000000                155.000000
# mean                  1.188898                  0.551341
# std                   0.287263                  0.237073
# min                   0.000000                  0.000000
# ...

# %%
Year_17_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 155 entries, 0 to 154
# Data columns (total 11 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Rank                           155 non-null    int64
#  1   Year                           155 non-null    int64
#  2   Country                        155 non-null    object
#  3   Region                         155 non-null    object
#  4   Happiness Score                155 non-null    float64
#  5   Economy (GDP per Capita)       155 non-null    float64
#  6   Family (Social Support)        155 non-null    float64
#  7   Health (Life Expectancy)       155 non-null    float64
#  8   Freedom (Life Choices)         155 non-null    float64
#  9   Trust (Government Corruption)  155 non-null    float64
#  10  Donations to Charity           155 non-null    float64
# dtypes: float64(7), int64(2), object(2)
# memory usage: 13.4+ KB

# %% [markdown]
#  4 Dataset of Year (2018)

# %%
Year_18.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Overall rank                  156 non-null    int64
#  1   Country or region             156 non-null    object
#  2   Score                         156 non-null    float64
#  3   GDP per capita                156 non-null    float64
#  4   Social support                156 non-null    float64
#  5   Healthy life expectancy       156 non-null    float64
#  6   Freedom to make life choices  156 non-null    float64
#  7   Generosity                    156 non-null    float64
#  8   Perceptions of corruption     155 non-null    float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 11.1+ KB

# %%
Year_18.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.632           1.305           1.592
# 1             2            Norway  7.594           1.456           1.582
# 2             3           Denmark  7.555           1.351           1.590
# 3             4           Iceland  7.495           1.343           1.644
# 4             5       Switzerland  7.487           1.420           1.549
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.874                         0.681       0.202
# 1                    0.861                         0.686       0.286
# 2                    0.868                         0.683       0.284
# 3                    0.914                         0.677       0.353
# 4                    0.927                         0.660       0.256
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.340
# ...

# %%
Year_18.describe()
# Out:
#        Overall rank       Score  GDP per capita  Social support  \
# count    156.000000  156.000000      156.000000      156.000000
# mean      78.500000    5.375917        0.891449        1.213237
# std       45.177428    1.119506        0.391921        0.302372
# min        1.000000    2.905000        0.000000        0.000000
# 25%       39.750000    4.453750        0.616250        1.066750
# 50%       78.500000    5.378000        0.949500        1.255000
# 75%      117.250000    6.168500        1.197750        1.463000
# max      156.000000    7.632000        2.096000        1.644000
#
#        Healthy life expectancy  Freedom to make life choices  Generosity  \
# count               156.000000                    156.000000  156.000000
# mean                  0.597346                      0.454506    0.181006
# std                   0.247579                      0.162424    0.098471
# min                   0.000000                      0.000000    0.000000
# ...

# %%
Year_18.rename(columns = {'Overall rank':'Rank', 'Country or region':'Country', 'Score':'Happiness Score', 'GDP per capita':'Economy (GDP per Capita)', 'Social support':'Family (Social Support)', 'Healthy life expectancy': 'Health (Life Expectancy)', 'Freedom to make life choices': 'Freedom (Life Choices)', 'Generosity':'Donations to Charity', 'Perceptions of corruption':'Trust (Government Corruption)'}, inplace = True)

# %%
# add new column
Year_18 ['Year'] = 2018

# %%
# Correcting country name 
Year_18['Country'] = Year_18['Country'].replace('South Sudan', 'Sudan')
Year_18['Country'] = Year_18['Country'].replace('Trinidad & Tobago', 'Trinidad and Tobago')

# %%
# derive Region according to country names using loc()
Year_18.loc[Year_18['Country'].isin(['Australia', 'New Zealand']), 'Region'] = 'Australia and New Zealand'

# %%
Year_18.loc[Year_18['Country'].isin(['Albania', 'Armenia', 'Azerbaijan', 'Belarus', 'Bosnia and Herzegovina', 'Bulgaria', 'Croatia', 'Czech Republic', 'Estonia', 'Georgia', 'Hungary', 'Kazakhstan', 'Kosovo', 'Kyrgyzstan', 'Latvia', 'Lithuania', 'Macedonia', 'Moldova', 'Montenegro', 'Poland','Romania', 'Russia', 'Serbia', 'Slovakia', 'Slovenia', 'Tajikistan', 'Turkmenistan', 'Ukraine', 'Uzbekistan']), 'Region'] = 'Central and Eastern Europe'

# %%
Year_18.loc[Year_18['Country'].isin(['China', 'Hong Kong', 'Japan', 'Mongolia', 'South Korea', 'Taiwan']), 'Region'] = 'Eastern Asia'

# %%
Year_18.loc[Year_18['Country'].isin(['Argentina', 'Bolivia', 'Brazil', 'Belize', 'Venezuela', 'Chile', 'Colombia', 'Costa Rica', 'Dominican Republic','Ecuador', 'El Salvador', 'Guatemala', 'Haiti', 'Honduras', 'Jamaica', 'Mexico', 'Nicaragua', 'Panama', 'Paraguay', 'Peru', 'Suriname', 'Trinidad and Tobago', 'Uruguay', 'Uruguay']), 'Region'] = 'Latin America and Caribbean'

# %%
Year_18.loc[Year_18['Country'].isin(['Algeria', 'Bahrain','Egypt','Iran', 'Iraq', 'Israel', 'Jordan', 'Kuwait', 'Lebanon', 'Libya', 'Morocco', 'Oman', 'Palestinian Territories', 'Qatar', 'Saudi Arabia', 'Syria', 'Tunisia', 'Turkey', 'United Arab Emirates', 'Yemen']), 'Region'] = 'Middle East and Northern Africa'

# %%
Year_18.loc[Year_18['Country'].isin(['Canada', 'United States']), 'Region'] = 'North America'

# %%
Year_18.loc[Year_18['Country'].isin(['Cambodia', 'Indonesia', 'Laos', 'Malaysia', 'Myanmar', 'Philippines', 'Singapore','Thailand', 'Vietnam']), 'Region'] = 'Southeastern Asia'

# %%
Year_18.loc[Year_18['Country'].isin(['Afghanistan', 'Bangladesh', 'Bhutan', 'India', 'Nepal', 'Pakistan', 'Sri Lanka']), 'Region'] = 'Southern Asia'

# %%
Year_18.loc[Year_18['Country'].isin(['Angola', 'Benin', 'Botswana', 'Burkina Faso', 'Burundi', 'Cameroon', 'Central African Republic', 'Chad', 'Comoros', 'Congo (Brazzaville)', 'Congo (Kinshasa)', 'Djibouti', 'Ethiopia', 'Gabon', 'Ghana', 'Guinea', 'Ivory Coast', 'Kenya', 'Lesotho', 'Liberia', 'Madagascar', 'Malawi', 'Mali', 'Mauritania', 'Mauritius', 'Mozambique', 'Niger', 'Nigeria', 'Rwanda', 'Senegal', 'Sierra Leone', 'Somaliland region', 'South Africa', 'Sudan', 'Swaziland', 'Tanzania', 'Togo', 'Uganda', 'Zambia', 'Zimbabwe', 'Somalia', 'Namibia']), 'Region'] = 'Sub-Saharan Africa'

# %%
Year_18.loc[Year_18['Country'].isin(['North Cyprus','Austria', 'Belgium', 'Cyprus', 'Denmark', 'Finland', 'France', 'Germany', 'Greece', 'Iceland', 'Ireland', 'Italy', 'Luxembourg', 'Malta', 'Netherlands', 'North Cyprus', 'Norway', 'Portugal', 'Spain', 'Sweden', 'Switzerland', 'United Kingdom']), 'Region'] = 'Western Europe'

# %%
Year_18.head()
# Out:
#    Rank      Country  Happiness Score  Economy (GDP per Capita)  \
# 0     1      Finland            7.632                     1.305
# 1     2       Norway            7.594                     1.456
# 2     3      Denmark            7.555                     1.351
# 3     4      Iceland            7.495                     1.343
# 4     5  Switzerland            7.487                     1.420
#
#    Family (Social Support)  Health (Life Expectancy)  Freedom (Life Choices)  \
# 0                    1.592                     0.874                   0.681
# 1                    1.582                     0.861                   0.686
# 2                    1.590                     0.868                   0.683
# 3                    1.644                     0.914                   0.677
# 4                    1.549                     0.927                   0.660
#
#    Donations to Charity  Trust (Government Corruption)  Year          Region
# ...

# %%
Year_18 = Year_18[['Rank', 'Year', 'Country', 'Region', 'Happiness Score', 'Economy (GDP per Capita)', 'Family (Social Support)', 'Health (Life Expectancy)', 'Freedom (Life Choices)', 'Trust (Government Corruption)', 'Donations to Charity']]

# %%
Year_18.head(5)
# Out:
#    Rank  Year      Country          Region  Happiness Score  \
# 0     1  2018      Finland  Western Europe            7.632
# 1     2  2018       Norway  Western Europe            7.594
# 2     3  2018      Denmark  Western Europe            7.555
# 3     4  2018      Iceland  Western Europe            7.495
# 4     5  2018  Switzerland  Western Europe            7.487
#
#    Economy (GDP per Capita)  Family (Social Support)  \
# 0                     1.305                    1.592
# 1                     1.456                    1.582
# 2                     1.351                    1.590
# 3                     1.343                    1.644
# 4                     1.420                    1.549
#
#    Health (Life Expectancy)  Freedom (Life Choices)  \
# 0                     0.874                   0.681
# 1                     0.861                   0.686
# 2                     0.868                   0.683
# 3                     0.914                   0.677
# ...

# %%
# checking the null value in data
Year_18.isnull().sum()
# Out:
# Rank                             0
# Year                             0
# Country                          0
# Region                           1
# Happiness Score                  0
# Economy (GDP per Capita)         0
# Family (Social Support)          0
# Health (Life Expectancy)         0
# Freedom (Life Choices)           0
# Trust (Government Corruption)    1
# Donations to Charity             0
# dtype: int64

# %%
print("Missing Data:\n", Year_18[Year_18.isnull().any(axis=1)])
# Out:
# Missing Data:
#      Rank  Year               Country                           Region  \
# 19    20  2018  United Arab Emirates  Middle East and Northern Africa
# 57    58  2018       Northern Cyprus                              NaN
#
#     Happiness Score  Economy (GDP per Capita)  Family (Social Support)  \
# 19            6.774                     2.096                    0.776
# 57            5.835                     1.229                    1.211
#
#     Health (Life Expectancy)  Freedom (Life Choices)  \
# 19                     0.670                   0.284
# 57                     0.909                   0.495
#
#     Trust (Government Corruption)  Donations to Charity
# 19                            NaN                 0.186
# 57                          0.154                 0.179

# %%
print("Missing Data:\n", Year_18[Year_18.isnull().any(axis=1)])
# Out:
# Missing Data:
#      Rank  Year               Country                           Region  \
# 19    20  2018  United Arab Emirates  Middle East and Northern Africa
# 57    58  2018       Northern Cyprus                              NaN
#
#     Happiness Score  Economy (GDP per Capita)  Family (Social Support)  \
# 19            6.774                     2.096                    0.776
# 57            5.835                     1.229                    1.211
#
#     Health (Life Expectancy)  Freedom (Life Choices)  \
# 19                     0.670                   0.284
# 57                     0.909                   0.495
#
#     Trust (Government Corruption)  Donations to Charity
# 19                            NaN                 0.186
# 57                          0.154                 0.179

# %%
Year_18['Country'] = Year_18['Country'].replace('Northern Cyprus', 'North Cyprus')

# %%
Year_18.loc[Year_18['Country'].isin(['North Cyprus']), 'Region'] = 'Western Europe'

# %%
print("Missing Data:\n", Year_18[Year_18.isnull().any(axis=1)])
# Out:
# Missing Data:
#      Rank  Year               Country                           Region  \
# 19    20  2018  United Arab Emirates  Middle East and Northern Africa
#
#     Happiness Score  Economy (GDP per Capita)  Family (Social Support)  \
# 19            6.774                     2.096                    0.776
#
#     Health (Life Expectancy)  Freedom (Life Choices)  \
# 19                      0.67                   0.284
#
#     Trust (Government Corruption)  Donations to Charity
# 19                            NaN                 0.186

# %%
# check for duplicates
Year_18[Year_18.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Rank, Year, Country, Region, Happiness Score, Economy (GDP per Capita), Family (Social Support), Health (Life Expectancy), Freedom (Life Choices), Trust (Government Corruption), Donations to Charity]
# Index: []

# %%
# drop the other missing values
Year_18_clean = Year_18.dropna()

# %%
Year_18_clean.shape
# Out:
# (155, 11)

# %%
Year_18_clean.describe()
# Out:
#              Rank    Year  Happiness Score  Economy (GDP per Capita)  \
# count  155.000000   155.0       155.000000                155.000000
# mean    78.877419  2018.0         5.366897                  0.883677
# std     45.076463     0.0         1.117433                  0.380942
# min      1.000000  2018.0         2.905000                  0.000000
# 25%     40.500000  2018.0         4.451500                  0.612500
# 50%     79.000000  2018.0         5.358000                  0.940000
# 75%    117.500000  2018.0         6.154000                  1.192500
# max    156.000000  2018.0         7.632000                  1.649000
#
#        Family (Social Support)  Health (Life Expectancy)  \
# count               155.000000                155.000000
# mean                  1.216058                  0.596877
# std                   0.301286                  0.248312
# min                   0.000000                  0.000000
# ...

# %%
Year_18_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 155 entries, 0 to 155
# Data columns (total 11 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Rank                           155 non-null    int64
#  1   Year                           155 non-null    int64
#  2   Country                        155 non-null    object
#  3   Region                         155 non-null    object
#  4   Happiness Score                155 non-null    float64
#  5   Economy (GDP per Capita)       155 non-null    float64
#  6   Family (Social Support)        155 non-null    float64
#  7   Health (Life Expectancy)       155 non-null    float64
#  8   Freedom (Life Choices)         155 non-null    float64
#  9   Trust (Government Corruption)  155 non-null    float64
#  10  Donations to Charity           155 non-null    float64
# dtypes: float64(7), int64(2), object(2)
# memory usage: 14.5+ KB

# %% [markdown]
#  5. Dataset of Year (2019)

# %%
# Shape of the Dataframe
Year_19.shape
# Out:
# (156, 9)

# %%
# Info of dataframe
Year_19.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Overall rank                  156 non-null    int64
#  1   Country or region             156 non-null    object
#  2   Score                         156 non-null    float64
#  3   GDP per capita                156 non-null    float64
#  4   Social support                156 non-null    float64
#  5   Healthy life expectancy       156 non-null    float64
#  6   Freedom to make life choices  156 non-null    float64
#  7   Generosity                    156 non-null    float64
#  8   Perceptions of corruption     156 non-null    float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 11.1+ KB

# %%
# Rename the columns
Year_19.rename(columns = {'Overall rank':'Rank', 'Country or region':'Country', 'Score':'Happiness Score', 'GDP per capita':'Economy (GDP per Capita)', 'Social support':'Family (Social Support)', 'Healthy life expectancy': 'Health (Life Expectancy)', 'Freedom to make life choices': 'Freedom (Life Choices)', 'Generosity':'Donations to Charity', 'Perceptions of corruption':'Trust (Government Corruption)'}, inplace = True)

# %%
# Correcting country name 
Year_19['Country'] = Year_19['Country'].replace('Northern Cyprus', 'North Cyprus')
Year_19['Country'] = Year_19['Country'].replace('North Macedonia', 'Macedonia')
# Correcting country name 
Year_19['Country'] = Year_19['Country'].replace('South Sudan', 'Sudan')
Year_19['Country'] = Year_19['Country'].replace('Trinidad & Tobago', 'Trinidad and Tobago')

# %%
# add new column
Year_19 ['Year'] = 2019

# %%
#derive Region according to country names using loc()
Year_19.loc[Year_19['Country'].isin(['Australia', 'New Zealand']), 'Region'] = 'Australia and New Zealand'

# %%
Year_19.loc[Year_19['Country'].isin(['Albania', 'Armenia', 'Azerbaijan', 'Belarus', 'Bosnia and Herzegovina', 'Bulgaria', 'Croatia', 'Czech Republic', 'Estonia', 'Georgia', 'Hungary', 'Kazakhstan', 'Kosovo', 'Kyrgyzstan', 'Latvia', 'Lithuania', 'Macedonia', 'Moldova', 'Montenegro', 'Poland','Romania', 'Russia', 'Serbia', 'Slovakia', 'Slovenia', 'Tajikistan', 'Turkmenistan', 'Ukraine', 'Uzbekistan']), 'Region'] = 'Central and Eastern Europe'

# %%
Year_19.loc[Year_19['Country'].isin(['China', 'Hong Kong', 'Japan', 'Mongolia', 'South Korea', 'Taiwan']), 'Region'] = 'Eastern Asia'

# %%
Year_19.loc[Year_19['Country'].isin(['Argentina', 'Bolivia', 'Brazil', 'Belize', 'Venezuela', 'Chile', 'Colombia', 'Costa Rica', 'Dominican Republic','Ecuador', 'El Salvador', 'Guatemala', 'Haiti', 'Honduras', 'Jamaica', 'Mexico', 'Nicaragua', 'Panama', 'Paraguay', 'Peru', 'Suriname', 'Trinidad and Tobago', 'Uruguay', 'Uruguay']), 'Region'] = 'Latin America and Caribbean'

# %%
Year_19.loc[Year_19['Country'].isin(['Algeria', 'Bahrain','Egypt','Iran', 'Iraq', 'Israel', 'Jordan', 'Kuwait', 'Lebanon', 'Libya', 'Morocco', 'Oman', 'Palestinian Territories', 'Qatar', 'Saudi Arabia', 'Syria', 'Tunisia', 'Turkey', 'United Arab Emirates', 'Yemen']), 'Region'] = 'Middle East and Northern Africa'

# %%
Year_19.loc[Year_19['Country'].isin(['Canada', 'United States']), 'Region'] = 'North America'

# %%
Year_19.loc[Year_19['Country'].isin(['Cambodia', 'Indonesia', 'Laos', 'Malaysia', 'Myanmar', 'Philippines', 'Singapore','Thailand', 'Vietnam']), 'Region'] = 'Southeastern Asia'

# %%
Year_19.loc[Year_19['Country'].isin(['Afghanistan', 'Bangladesh', 'Bhutan', 'India', 'Nepal', 'Pakistan', 'Sri Lanka']), 'Region'] = 'Southern Asia'

# %%
Year_19.loc[Year_19['Country'].isin(['Angola', 'Benin', 'Botswana', 'Burkina Faso', 'Burundi', 'Cameroon', 'Central African Republic', 'Chad', 'Comoros', 'Congo (Brazzaville)', 'Congo (Kinshasa)', 'Djibouti', 'Ethiopia', 'Gabon', 'Ghana', 'Guinea', 'Ivory Coast', 'Kenya', 'Lesotho', 'Liberia', 'Madagascar', 'Malawi', 'Mali', 'Mauritania', 'Mauritius', 'Mozambique', 'Niger', 'Nigeria', 'Rwanda', 'Senegal', 'Sierra Leone', 'Gambia','Somaliland region', 'South Africa', 'Sudan', 'Swaziland', 'Tanzania', 'Togo', 'Uganda', 'Zambia', 'Zimbabwe', 'Somalia', 'Namibia']), 'Region'] = 'Sub-Saharan Africa'

# %%
Year_19.loc[Year_19['Country'].isin(['Austria', 'Belgium', 'Cyprus', 'Denmark', 'Finland', 'France', 'Germany', 'Greece', 'Iceland', 'Ireland', 'Italy', 'Luxembourg', 'Malta', 'Netherlands', 'North Cyprus', 'Norway', 'Portugal', 'Spain', 'Sweden', 'Switzerland', 'United Kingdom']), 'Region'] = 'Western Europe'

# %%
#change the order of columns
Year_19 = Year_19[['Rank', 'Year', 'Country', 'Region', 'Happiness Score', 'Economy (GDP per Capita)', 'Family (Social Support)', 'Health (Life Expectancy)', 'Freedom (Life Choices)', 'Trust (Government Corruption)', 'Donations to Charity']]

# %%
# check for duplicates
Year_19[Year_19.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Rank, Year, Country, Region, Happiness Score, Economy (GDP per Capita), Family (Social Support), Health (Life Expectancy), Freedom (Life Choices), Trust (Government Corruption), Donations to Charity]
# Index: []

# %%
Year_19.rename(columns = {'Generosity':'Donations to Charity'}, inplace = True)

# %%
Year_19.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 11 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Rank                           156 non-null    int64
#  1   Year                           156 non-null    int64
#  2   Country                        156 non-null    object
#  3   Region                         156 non-null    object
#  4   Happiness Score                156 non-null    float64
#  5   Economy (GDP per Capita)       156 non-null    float64
#  6   Family (Social Support)        156 non-null    float64
#  7   Health (Life Expectancy)       156 non-null    float64
#  8   Freedom (Life Choices)         156 non-null    float64
#  9   Trust (Government Corruption)  156 non-null    float64
#  10  Donations to Charity           156 non-null    float64
# dtypes: float64(7), int64(2), object(2)
# memory usage: 13.5+ KB

# %%
# drop the other missing values
Year_19_clean = Year_19.dropna()

# %%
Year_19_clean.shape
# Out:
# (156, 11)

# %%
Year_19_clean.describe()
# Out:
#              Rank    Year  Happiness Score  Economy (GDP per Capita)  \
# count  156.000000   156.0       156.000000                156.000000
# mean    78.500000  2019.0         5.407096                  0.905147
# std     45.177428     0.0         1.113120                  0.398389
# min      1.000000  2019.0         2.853000                  0.000000
# 25%     39.750000  2019.0         4.544500                  0.602750
# 50%     78.500000  2019.0         5.379500                  0.960000
# 75%    117.250000  2019.0         6.184500                  1.232500
# max    156.000000  2019.0         7.769000                  1.684000
#
#        Family (Social Support)  Health (Life Expectancy)  \
# count               156.000000                156.000000
# mean                  1.208814                  0.725244
# std                   0.299191                  0.242124
# min                   0.000000                  0.000000
# ...

# %%
Year_19_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 11 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Rank                           156 non-null    int64
#  1   Year                           156 non-null    int64
#  2   Country                        156 non-null    object
#  3   Region                         156 non-null    object
#  4   Happiness Score                156 non-null    float64
#  5   Economy (GDP per Capita)       156 non-null    float64
#  6   Family (Social Support)        156 non-null    float64
#  7   Health (Life Expectancy)       156 non-null    float64
#  8   Freedom (Life Choices)         156 non-null    float64
#  9   Trust (Government Corruption)  156 non-null    float64
#  10  Donations to Charity           156 non-null    float64
# dtypes: float64(7), int64(2), object(2)
# memory usage: 13.5+ KB

# %% [markdown]
#  6.Dataset of Year (2019)

# %%
# Shape of the Dataframe
Year_19.shape
# Out:
# (156, 11)

# %%
# Info of dataframe
Year_19.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 11 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Rank                           156 non-null    int64
#  1   Year                           156 non-null    int64
#  2   Country                        156 non-null    object
#  3   Region                         156 non-null    object
#  4   Happiness Score                156 non-null    float64
#  5   Economy (GDP per Capita)       156 non-null    float64
#  6   Family (Social Support)        156 non-null    float64
#  7   Health (Life Expectancy)       156 non-null    float64
#  8   Freedom (Life Choices)         156 non-null    float64
#  9   Trust (Government Corruption)  156 non-null    float64
#  10  Donations to Charity           156 non-null    float64
# dtypes: float64(7), int64(2), object(2)
# memory usage: 13.5+ KB

# %%
# add new column
Year_19 ['Year'] = 2019

# %%
# Rename the columns
Year_19.rename(columns = {'Overall rank':'Rank', 'Country or region':'Country', 'Score':'Happiness Score', 'GDP per capita':'Economy (GDP per Capita)', 'Social support':'Family (Social Support)', 'Healthy life expectancy': 'Health (Life Expectancy)', 'Freedom to make life choices': 'Freedom (Life Choices)', 'Generosity':'Donations to Charity', 'Perceptions of corruption':'Trust (Government Corruption)'}, inplace = True)

# %%
# Correcting country name 
Year_19['Country'] = Year_19['Country'].replace('Northern Cyprus', 'North Cyprus')
Year_19['Country'] = Year_19['Country'].replace('North Macedonia', 'Macedonia')
# Correcting country name 
Year_19['Country'] = Year_19['Country'].replace('South Sudan', 'Sudan')
Year_19['Country'] = Year_19['Country'].replace('Trinidad & Tobago', 'Trinidad and Tobago')

# %%
#derive Region according to country names using loc()
Year_19.loc[Year_19['Country'].isin(['Australia', 'New Zealand']), 'Region'] = 'Australia and New Zealand'

# %%
Year_19.loc[Year_19['Country'].isin(['Albania', 'Armenia', 'Azerbaijan', 'Belarus', 'Bosnia and Herzegovina', 'Bulgaria', 'Croatia', 'Czech Republic', 'Estonia', 'Georgia', 'Hungary', 'Kazakhstan', 'Kosovo', 'Kyrgyzstan', 'Latvia', 'Lithuania', 'Macedonia', 'Moldova', 'Montenegro', 'Poland','Romania', 'Russia', 'Serbia', 'Slovakia', 'Slovenia', 'Tajikistan', 'Turkmenistan', 'Ukraine', 'Uzbekistan']), 'Region'] = 'Central and Eastern Europe'

# %%
Year_19.loc[Year_19['Country'].isin(['Albania', 'Armenia', 'Azerbaijan', 'Belarus', 'Bosnia and Herzegovina', 'Bulgaria', 'Croatia', 'Czech Republic', 'Estonia', 'Georgia', 'Hungary', 'Kazakhstan', 'Kosovo', 'Kyrgyzstan', 'Latvia', 'Lithuania', 'Macedonia', 'Moldova', 'Montenegro', 'Poland','Romania', 'Russia', 'Serbia', 'Slovakia', 'Slovenia', 'Tajikistan', 'Turkmenistan', 'Ukraine', 'Uzbekistan']), 'Region'] = 'Central and Eastern Europe'

# %%
Year_19.loc[Year_19['Country'].isin(['Argentina', 'Bolivia', 'Brazil', 'Belize', 'Venezuela', 'Chile', 'Colombia', 'Costa Rica', 'Dominican Republic','Ecuador', 'El Salvador', 'Guatemala', 'Haiti', 'Honduras', 'Jamaica', 'Mexico', 'Nicaragua', 'Panama', 'Paraguay', 'Peru', 'Suriname', 'Trinidad and Tobago', 'Uruguay', 'Uruguay']), 'Region'] = 'Latin America and Caribbean'

# %%
Year_19.loc[Year_19['Country'].isin(['Algeria', 'Bahrain','Egypt','Iran', 'Iraq', 'Israel', 'Jordan', 'Kuwait', 'Lebanon', 'Libya', 'Morocco', 'Oman', 'Palestinian Territories', 'Qatar', 'Saudi Arabia', 'Syria', 'Tunisia', 'Turkey', 'United Arab Emirates', 'Yemen']), 'Region'] = 'Middle East and Northern Africa'

# %%
Year_19.loc[Year_19['Country'].isin(['Canada', 'United States']), 'Region'] = 'North America'

# %%
Year_19.loc[Year_19['Country'].isin(['Cambodia', 'Indonesia', 'Laos', 'Malaysia', 'Myanmar', 'Philippines', 'Singapore','Thailand', 'Vietnam']), 'Region'] = 'Southeastern Asia'

# %%
Year_19.loc[Year_19['Country'].isin(['Afghanistan', 'Bangladesh', 'Bhutan', 'India', 'Nepal', 'Pakistan', 'Sri Lanka']), 'Region'] = 'Southern Asia'

# %%
Year_19.loc[Year_19['Country'].isin(['Angola', 'Benin', 'Botswana', 'Burkina Faso', 'Burundi', 'Cameroon', 'Central African Republic', 'Chad', 'Comoros', 'Congo (Brazzaville)', 'Congo (Kinshasa)', 'Djibouti', 'Ethiopia', 'Gabon', 'Ghana', 'Guinea', 'Ivory Coast', 'Kenya', 'Lesotho', 'Liberia', 'Madagascar', 'Malawi', 'Mali', 'Mauritania', 'Mauritius', 'Mozambique', 'Niger', 'Nigeria', 'Rwanda', 'Senegal', 'Sierra Leone', 'Gambia','Somaliland region', 'South Africa', 'Sudan', 'Swaziland', 'Tanzania', 'Togo', 'Uganda', 'Zambia', 'Zimbabwe', 'Somalia', 'Namibia']), 'Region'] = 'Sub-Saharan Africa'

# %%
Year_19.loc[Year_19['Country'].isin(['Austria', 'Belgium', 'Cyprus', 'Denmark', 'Finland', 'France', 'Germany', 'Greece', 'Iceland', 'Ireland', 'Italy', 'Luxembourg', 'Malta', 'Netherlands', 'North Cyprus', 'Norway', 'Portugal', 'Spain', 'Sweden', 'Switzerland', 'United Kingdom']), 'Region'] = 'Western Europe'

# %%
Year_19 = Year_19[['Rank', 'Year', 'Country', 'Region', 'Happiness Score', 'Economy (GDP per Capita)', 'Family (Social Support)', 'Health (Life Expectancy)', 'Freedom (Life Choices)', 'Trust (Government Corruption)', 'Donations to Charity']]

# %%
#change the order of columns
Year_19 = Year_19[['Rank', 'Year', 'Country', 'Region', 'Happiness Score', 'Economy (GDP per Capita)', 'Family (Social Support)', 'Health (Life Expectancy)', 'Freedom (Life Choices)', 'Trust (Government Corruption)', 'Donations to Charity']]

# %%
# check for duplicates
Year_19[Year_19.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Rank, Year, Country, Region, Happiness Score, Economy (GDP per Capita), Family (Social Support), Health (Life Expectancy), Freedom (Life Choices), Trust (Government Corruption), Donations to Charity]
# Index: []

# %%
# checking the null data
Year_19.isnull().sum()
# Out:
# Rank                             0
# Year                             0
# Country                          0
# Region                           0
# Happiness Score                  0
# Economy (GDP per Capita)         0
# Family (Social Support)          0
# Health (Life Expectancy)         0
# Freedom (Life Choices)           0
# Trust (Government Corruption)    0
# Donations to Charity             0
# dtype: int64

# %%
Year_19.head()
# Out:
#    Rank  Year      Country          Region  Happiness Score  \
# 0     1  2019      Finland  Western Europe            7.769
# 1     2  2019      Denmark  Western Europe            7.600
# 2     3  2019       Norway  Western Europe            7.554
# 3     4  2019      Iceland  Western Europe            7.494
# 4     5  2019  Netherlands  Western Europe            7.488
#
#    Economy (GDP per Capita)  Family (Social Support)  \
# 0                     1.340                    1.587
# 1                     1.383                    1.573
# 2                     1.488                    1.582
# 3                     1.380                    1.624
# 4                     1.396                    1.522
#
#    Health (Life Expectancy)  Freedom (Life Choices)  \
# 0                     0.986                   0.596
# 1                     0.996                   0.592
# 2                     1.028                   0.603
# 3                     1.026                   0.591
# ...

# %%
# drop the other missing values
Year_19_clean = Year_19.dropna()

# %%
Year_19_clean.shape
# Out:
# (156, 11)

# %%
Year_19_clean.describe ()
# Out:
#              Rank    Year  Happiness Score  Economy (GDP per Capita)  \
# count  156.000000   156.0       156.000000                156.000000
# mean    78.500000  2019.0         5.407096                  0.905147
# std     45.177428     0.0         1.113120                  0.398389
# min      1.000000  2019.0         2.853000                  0.000000
# 25%     39.750000  2019.0         4.544500                  0.602750
# 50%     78.500000  2019.0         5.379500                  0.960000
# 75%    117.250000  2019.0         6.184500                  1.232500
# max    156.000000  2019.0         7.769000                  1.684000
#
#        Family (Social Support)  Health (Life Expectancy)  \
# count               156.000000                156.000000
# mean                  1.208814                  0.725244
# std                   0.299191                  0.242124
# min                   0.000000                  0.000000
# ...

# %%
Year_19_clean.info ()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 11 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Rank                           156 non-null    int64
#  1   Year                           156 non-null    int64
#  2   Country                        156 non-null    object
#  3   Region                         156 non-null    object
#  4   Happiness Score                156 non-null    float64
#  5   Economy (GDP per Capita)       156 non-null    float64
#  6   Family (Social Support)        156 non-null    float64
#  7   Health (Life Expectancy)       156 non-null    float64
#  8   Freedom (Life Choices)         156 non-null    float64
#  9   Trust (Government Corruption)  156 non-null    float64
#  10  Donations to Charity           156 non-null    float64
# dtypes: float64(7), int64(2), object(2)
# memory usage: 13.5+ KB

# %% [markdown]
#  6. Dataset of Year (2020)

# %%
# Shape of the Dataframe
Year_20.shape
# Out:
# (153, 20)

# %%
Year_20.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 153 entries, 0 to 152
# Data columns (total 20 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Country name                                153 non-null    object
#  1   Regional indicator                          153 non-null    object
#  2   Ladder score                                153 non-null    float64
#  3   Standard error of ladder score              153 non-null    float64
#  4   upperwhisker                                153 non-null    float64
#  5   lowerwhisker                                153 non-null    float64
#  6   Logged GDP per capita                       153 non-null    float64
#  7   Social support                              153 non-null    float64
#  8   Healthy life expectancy                     153 non-null    float64
# ...

# %%
Year_20.describe()
# Out:
#        Ladder score  Standard error of ladder score  upperwhisker  \
# count     153.00000                      153.000000    153.000000
# mean        5.47324                        0.053538      5.578175
# std         1.11227                        0.018183      1.096823
# min         2.56690                        0.025902      2.628270
# 25%         4.72410                        0.040698      4.826248
# 50%         5.51500                        0.050606      5.607728
# 75%         6.22850                        0.060677      6.363886
# max         7.80870                        0.120590      7.869766
#
#        lowerwhisker  Logged GDP per capita  Social support  \
# count    153.000000             153.000000      153.000000
# mean       5.368304               9.295706        0.808721
# std        1.128631               1.201588        0.121453
# min        2.505530               6.492642        0.319460
# 25%        4.603149               8.350645        0.737217
# ...

# %%
# add new column
Year_20 ['Year'] = 2020

# %%
# Remove unnecessary columns
Year_20.drop(['Standard error of ladder score', 'upperwhisker','lowerwhisker', 'Logged GDP per capita', 'Social support','Healthy life expectancy','Freedom to make life choices', 'Generosity', 'Perceptions of corruption','Ladder score in Dystopia'], axis=1, inplace=True)

# %%
# rename columns
Year_20.rename(columns = {'Country name':'Country', 'Regional indicator':'Region', 'Ladder score':'Happiness Score', 'Explained by: Log GDP per capita':'Economy (GDP per Capita)', 'Explained by: Social support':'Family (Social Support)', 'Explained by: Healthy life expectancy': 'Health (Life Expectancy)', 'Explained by: Freedom to make life choices': 'Freedom (Life Choices)', 'Explained by: Generosity':'Donations to Charity', 'Explained by: Perceptions of corruption':'Trust (Government Corruption)'}, inplace = True)

# %%
# Add the "Rank" column
Year_20['Rank'] = range(1, len(Year_20) + 1)

# %%
#remove unnecessary columns
Year_20.drop(['Dystopia + residual'], axis=1, inplace=True)

# %%
# change the order of columns
Year_20 = Year_20[['Rank', 'Year', 'Country', 'Region', 'Happiness Score', 'Economy (GDP per Capita)', 'Family (Social Support)', 'Health (Life Expectancy)', 'Freedom (Life Choices)', 'Trust (Government Corruption)', 'Donations to Charity']]

# %%
# checking the null data
Year_20.isnull().sum()
# Out:
# Rank                             0
# Year                             0
# Country                          0
# Region                           0
# Happiness Score                  0
# Economy (GDP per Capita)         0
# Family (Social Support)          0
# Health (Life Expectancy)         0
# Freedom (Life Choices)           0
# Trust (Government Corruption)    0
# Donations to Charity             0
# dtype: int64

# %%
# check for duplicates
Year_20[Year_20.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Rank, Year, Country, Region, Happiness Score, Economy (GDP per Capita), Family (Social Support), Health (Life Expectancy), Freedom (Life Choices), Trust (Government Corruption), Donations to Charity]
# Index: []

# %%
# drop the other missing values
Year_20_clean = Year_20.dropna()

# %%
Year_20_clean.shape
# Out:
# (153, 11)

# %%
Year_20_clean.describe()
# Out:
#              Rank    Year  Happiness Score  Economy (GDP per Capita)  \
# count  153.000000   153.0        153.00000                153.000000
# mean    77.000000  2020.0          5.47324                  0.868771
# std     44.311398     0.0          1.11227                  0.372416
# min      1.000000  2020.0          2.56690                  0.000000
# 25%     39.000000  2020.0          4.72410                  0.575862
# 50%     77.000000  2020.0          5.51500                  0.918549
# 75%    115.000000  2020.0          6.22850                  1.169229
# max    153.000000  2020.0          7.80870                  1.536676
#
#        Family (Social Support)  Health (Life Expectancy)  \
# count               153.000000                153.000000
# mean                  1.155607                  0.692869
# std                   0.286866                  0.254094
# min                   0.000000                  0.000000
# ...

# %%
Year_20_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 153 entries, 0 to 152
# Data columns (total 11 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Rank                           153 non-null    int64
#  1   Year                           153 non-null    int64
#  2   Country                        153 non-null    object
#  3   Region                         153 non-null    object
#  4   Happiness Score                153 non-null    float64
#  5   Economy (GDP per Capita)       153 non-null    float64
#  6   Family (Social Support)        153 non-null    float64
#  7   Health (Life Expectancy)       153 non-null    float64
#  8   Freedom (Life Choices)         153 non-null    float64
#  9   Trust (Government Corruption)  153 non-null    float64
#  10  Donations to Charity           153 non-null    float64
# dtypes: float64(7), int64(2), object(2)
# memory usage: 13.3+ KB

# %% [markdown]
#  7. Dataset of Year (2021)

# %%
# check the shape of the Dataframe
Year_21.shape
# Out:
# (149, 20)

# %%
# check the info of dataframe
Year_21.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149 entries, 0 to 148
# Data columns (total 20 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Country name                                149 non-null    object
#  1   Regional indicator                          149 non-null    object
#  2   Ladder score                                149 non-null    float64
#  3   Standard error of ladder score              149 non-null    float64
#  4   upperwhisker                                149 non-null    float64
#  5   lowerwhisker                                149 non-null    float64
#  6   Logged GDP per capita                       149 non-null    float64
#  7   Social support                              149 non-null    float64
#  8   Healthy life expectancy                     149 non-null    float64
# ...

# %%
# add new column
Year_21 ['Year'] = 2021

# %%
#remove unnecessary columns

Year_21.drop(['Standard error of ladder score', 'upperwhisker','lowerwhisker', 'Logged GDP per capita', 'Social support','Healthy life expectancy','Freedom to make life choices', 'Generosity', 'Perceptions of corruption','Ladder score in Dystopia'], axis=1, inplace=True)

# %%
Year_21.head(5)
# Out:
#   Country name Regional indicator  Ladder score  \
# 0      Finland     Western Europe         7.842
# 1      Denmark     Western Europe         7.620
# 2  Switzerland     Western Europe         7.571
# 3      Iceland     Western Europe         7.554
# 4  Netherlands     Western Europe         7.464
#
#    Explained by: Log GDP per capita  Explained by: Social support  \
# 0                             1.446                         1.106
# 1                             1.502                         1.108
# 2                             1.566                         1.079
# 3                             1.482                         1.172
# 4                             1.501                         1.079
#
#    Explained by: Healthy life expectancy  \
# 0                                  0.741
# 1                                  0.763
# 2                                  0.816
# 3                                  0.772
# 4                                  0.753
#
# ...

# %%
# rename columns
Year_21.rename(columns = {'Country name':'Country', 'Regional indicator':'Region', 'Ladder score':'Happiness Score', 'Explained by: Log GDP per capita':'Economy (GDP per Capita)', 'Explained by: Social support':'Family (Social Support)', 'Explained by: Healthy life expectancy': 'Health (Life Expectancy)', 'Explained by: Freedom to make life choices': 'Freedom (Life Choices)', 'Explained by: Generosity':'Donations to Charity', 'Explained by: Perceptions of corruption':'Trust (Government Corruption)'}, inplace = True)

# %%
# Add the "Rank" column
Year_21['Rank'] = range(1, len(Year_21) + 1)

# %%
#remove unnecessary columns
Year_21.drop(['Dystopia + residual'], axis=1, inplace=True)

# %%
#change the order of columns
Year_21 = Year_21[['Rank', 'Year', 'Country', 'Region', 'Happiness Score', 'Economy (GDP per Capita)', 'Family (Social Support)', 'Health (Life Expectancy)', 'Freedom (Life Choices)', 'Trust (Government Corruption)', 'Donations to Charity']]

# %%
# checking the null data
Year_21.isnull().sum()
# Out:
# Rank                             0
# Year                             0
# Country                          0
# Region                           0
# Happiness Score                  0
# Economy (GDP per Capita)         0
# Family (Social Support)          0
# Health (Life Expectancy)         0
# Freedom (Life Choices)           0
# Trust (Government Corruption)    0
# Donations to Charity             0
# dtype: int64

# %%
# check for duplicates
Year_21[Year_21.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Rank, Year, Country, Region, Happiness Score, Economy (GDP per Capita), Family (Social Support), Health (Life Expectancy), Freedom (Life Choices), Trust (Government Corruption), Donations to Charity]
# Index: []

# %%
# drop the other missing values
Year_21_clean = Year_21.dropna()

# %%
Year_21_clean.shape
# Out:
# (149, 11)

# %%
Year_21_clean.describe()
# Out:
#              Rank    Year  Happiness Score  Economy (GDP per Capita)  \
# count  149.000000   149.0       149.000000                149.000000
# mean    75.000000  2021.0         5.532839                  0.977161
# std     43.156691     0.0         1.073924                  0.404740
# min      1.000000  2021.0         2.523000                  0.000000
# 25%     38.000000  2021.0         4.852000                  0.666000
# 50%     75.000000  2021.0         5.534000                  1.025000
# 75%    112.000000  2021.0         6.255000                  1.323000
# max    149.000000  2021.0         7.842000                  1.751000
#
#        Family (Social Support)  Health (Life Expectancy)  \
# count               149.000000                149.000000
# mean                  0.793315                  0.520161
# std                   0.258871                  0.213019
# min                   0.000000                  0.000000
# ...

# %%
Year_21_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149 entries, 0 to 148
# Data columns (total 11 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Rank                           149 non-null    int64
#  1   Year                           149 non-null    int64
#  2   Country                        149 non-null    object
#  3   Region                         149 non-null    object
#  4   Happiness Score                149 non-null    float64
#  5   Economy (GDP per Capita)       149 non-null    float64
#  6   Family (Social Support)        149 non-null    float64
#  7   Health (Life Expectancy)       149 non-null    float64
#  8   Freedom (Life Choices)         149 non-null    float64
#  9   Trust (Government Corruption)  149 non-null    float64
#  10  Donations to Charity           149 non-null    float64
# dtypes: float64(7), int64(2), object(2)
# memory usage: 12.9+ KB

# %% [markdown]
#  # 8. Dataset of Year (2022)

# %%
Year_22.shape
# Out:
# (147, 12)

# %%
Year_22.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 147 entries, 0 to 146
# Data columns (total 12 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   RANK                                        147 non-null    int64
#  1   Country                                     147 non-null    object
#  2   Happiness score                             146 non-null    object
#  3   Whisker-high                                146 non-null    object
#  4   Whisker-low                                 146 non-null    object
#  5   Dystopia (1.83) + residual                  146 non-null    object
#  6   Explained by: GDP per capita                146 non-null    object
#  7   Explained by: Social support                146 non-null    object
#  8   Explained by: Healthy life expectancy       146 non-null    object
#  9   Explained by: Freedom to make life choices  146 non-null    object
# ...

# %%
Year_22.describe()
# Out:
#              RANK
# count  147.000000
# mean    74.000000
# std     42.579338
# min      1.000000
# 25%     37.500000
# 50%     74.000000
# 75%    110.500000
# max    147.000000

# %%
# add new column
Year_22 ['Year'] = 2022

# %%
#remove unnecessary columns
Year_22.drop(['Whisker-high','Whisker-low', 'Dystopia (1.83) + residual'], axis=1, inplace=True)

# %%
# rename columns
Year_22.rename(columns = {'Country name':'Country', 'Regional indicator':'Region', 'Ladder score':'Happiness Score', 'Explained by: Log GDP per capita':'Economy (GDP per Capita)', 'Explained by: Social support':'Family (Social Support)', 'Explained by: Healthy life expectancy': 'Health (Life Expectancy)', 'Explained by: Freedom to make life choices': 'Freedom (Life Choices)', 'Explained by: Generosity':'Donations to Charity', 'Explained by: Perceptions of corruption':'Trust (Government Corruption)'}, inplace = True)

# %%
# Add the "Rank" column
Year_22['Rank'] = range(1, len(Year_22) + 1)

# %%
Year_22.describe()
# Out:
#              RANK    Year        Rank
# count  147.000000   147.0  147.000000
# mean    74.000000  2022.0   74.000000
# std     42.579338     0.0   42.579338
# min      1.000000  2022.0    1.000000
# 25%     37.500000  2022.0   37.500000
# 50%     74.000000  2022.0   74.000000
# 75%    110.500000  2022.0  110.500000
# max    147.000000  2022.0  147.000000

# %%
Year_22.drop(['Rank'], axis=1, inplace=True)

# %%
Year_22.describe()
# Out:
#              RANK    Year
# count  147.000000   147.0
# mean    74.000000  2022.0
# std     42.579338     0.0
# min      1.000000  2022.0
# 25%     37.500000  2022.0
# 50%     74.000000  2022.0
# 75%    110.500000  2022.0
# max    147.000000  2022.0

# %%
# Correcting country name 
Year_22['Country'] = Year_22['Country'].replace('Northern Cyprus', 'North Cyprus')
Year_22['Country'] = Year_22['Country'].replace('North Macedonia', 'Macedonia')
Year_22['Country'] = Year_22['Country'].replace('South Sudan', 'Sudan')
Year_22['Country'] = Year_22['Country'].replace('Trinidad & Tobago', 'Trinidad and Tobago')

# %%
# Correcting country name 
Year_22['Country'] = Year_22['Country'].replace('Luxembourg*', 'Luxembourg')
Year_22['Country'] = Year_22['Country'].replace('Czechia', 'Czech Republic')
Year_22['Country'] = Year_22['Country'].replace('Taiwan Province of China', 'Taiwan')
Year_22['Country'] = Year_22['Country'].replace('Guatemala*', 'Guatemala')
Year_22['Country'] = Year_22['Country'].replace('Kuwait*', 'Kuwait')
Year_22['Country'] = Year_22['Country'].replace('Belarus*', 'Belarus')
Year_22['Country'] = Year_22['Country'].replace('North Cyprus*', 'North Cyprus')
Year_22['Country'] = Year_22['Country'].replace('Hong Kong S.A.R. of China', 'Hong Kong')
Year_22['Country'] = Year_22['Country'].replace('Libya*', 'Libya')
Year_22['Country'] = Year_22['Country'].replace('Turkmenistan*', 'Turkmenistan')
Year_22['Country'] = Year_22['Country'].replace('Congo', 'Congo (Brazzaville)')
Year_22['Country'] = Year_22['Country'].replace('Niger*', 'Niger')

# %%
# Correcting country name 
Year_22['Country'] = Year_22['Country'].replace('Comoros*', 'Comoros')
Year_22['Country'] = Year_22['Country'].replace('Palestinian Territories*', 'Palestinian Territories')
Year_22['Country'] = Year_22['Country'].replace('Eswatini, Kingdom of*', 'Eswatini, Kingdom of')
Year_22['Country'] = Year_22['Country'].replace('Madagascar*', 'Madagascar')
Year_22['Country'] = Year_22['Country'].replace('Chad*', 'Chad')
Year_22['Country'] = Year_22['Country'].replace('Yemen*', 'Yemen')
Year_22['Country'] = Year_22['Country'].replace('Mauritania*', 'Mauritania')
Year_22['Country'] = Year_22['Country'].replace('Lesotho*', 'Lesotho')
Year_22['Country'] = Year_22['Country'].replace('Botswana*', 'Botswana')
Year_22['Country'] = Year_22['Country'].replace('Rwanda*', 'Rwanda')
Year_22['Country'] = Year_22['Country'].replace('Azerbaijan*', 'Azerbaijan')
Year_22['Country'] = Year_22['Country'].replace('Gambia*', 'Gambia')
Year_22['Country'] = Year_22['Country'].replace('Liberia*', 'Liberia')

# %%
# derive Region according to country names using loc()
Year_22.loc[Year_22['Country'].isin(['Australia', 'New Zealand']), 'Region'] = 'Australia and New Zealand'

# %%
Year_22.loc[Year_22['Country'].isin(['Albania', 'Armenia', 'Azerbaijan', 'Belarus', 'Bosnia and Herzegovina', 'Bulgaria', 'Croatia', 'Czech Republic', 'Estonia', 'Georgia', 'Hungary', 'Kazakhstan', 'Kosovo', 'Kyrgyzstan', 'Latvia', 'Lithuania', 'Macedonia', 'Moldova', 'Montenegro', 'Poland','Romania', 'Russia', 'Serbia', 'Slovakia', 'Slovenia', 'Tajikistan', 'Turkmenistan', 'Ukraine', 'Uzbekistan']), 'Region'] = 'Central and Eastern Europe'

# %%
Year_22.loc[Year_22['Country'].isin(['China', 'Hong Kong', 'Japan', 'Mongolia', 'South Korea', 'Taiwan']), 'Region'] = 'Eastern Asia'

# %%
Year_22.loc[Year_22['Country'].isin(['Argentina', 'Bolivia', 'Brazil', 'Belize', 'Venezuela', 'Chile', 'Colombia', 'Costa Rica', 'Dominican Republic','Ecuador', 'El Salvador', 'Guatemala', 'Haiti', 'Honduras', 'Jamaica', 'Mexico', 'Nicaragua', 'Panama', 'Paraguay', 'Peru', 'Suriname', 'Trinidad and Tobago', 'Uruguay', 'Uruguay']), 'Region'] = 'Latin America and Caribbean'

# %%
Year_22.loc[Year_22['Country'].isin(['Algeria', 'Bahrain','Egypt','Iran', 'Iraq', 'Israel', 'Jordan', 'Kuwait', 'Lebanon', 'Libya', 'Morocco', 'Oman', 'Palestinian Territories', 'Qatar', 'Saudi Arabia', 'Syria', 'Tunisia', 'Turkey', 'United Arab Emirates', 'Yemen']), 'Region'] = 'Middle East and Northern Africa'

# %%
Year_22.loc[Year_22['Country'].isin(['Canada', 'United States']), 'Region'] = 'North America'

# %%
Year_22.loc[Year_22['Country'].isin(['Cambodia', 'Indonesia', 'Laos', 'Malaysia', 'Myanmar', 'Philippines', 'Singapore','Thailand', 'Vietnam']), 'Region'] = 'Southeastern Asia'

# %%
Year_22.loc[Year_22['Country'].isin(['Afghanistan', 'Bangladesh', 'Bhutan', 'India', 'Nepal', 'Pakistan', 'Sri Lanka']), 'Region'] = 'Southern Asia'

# %%
Year_22.loc[Year_22['Country'].isin(['Angola', 'Benin', 'Botswana', 'Burkina Faso', 'Burundi', 'Cameroon', 'Central African Republic', 'Chad', 'Comoros', 'Congo (Brazzaville)', 'Congo (Kinshasa)', 'Djibouti', 'Ethiopia', 'Gabon', 'Ghana', 'Guinea', 'Ivory Coast', 'Kenya', 'Lesotho', 'Liberia', 'Madagascar', 'Malawi', 'Mali', 'Mauritania', 'Mauritius', 'Mozambique', 'Niger', 'Nigeria', 'Rwanda', 'Senegal', 'Sierra Leone', 'Gambia','Somaliland region', 'South Africa', 'Sudan', 'Swaziland', 'Tanzania', 'Togo', 'Uganda', 'Zambia', 'Zimbabwe', 'Somalia', 'Namibia']), 'Region'] = 'Sub-Saharan Africa'

# %%
Year_22.loc[Year_22['Country'].isin(['Austria', 'Belgium', 'Cyprus', 'Denmark', 'Finland', 'France', 'Germany', 'Greece', 'Iceland', 'Ireland', 'Italy', 'Luxembourg', 'Malta', 'Netherlands', 'North Cyprus', 'Norway', 'Portugal', 'Spain', 'Sweden', 'Switzerland', 'United Kingdom']), 'Region'] = 'Western Europe'

# %%
#change the order of columns
Year_22 = Year_22[['RANK', 'Year', 'Country', 'Region', 'Happiness score', 'Explained by: GDP per capita', 'Family (Social Support)', 'Health (Life Expectancy)', 'Freedom (Life Choices)', 'Trust (Government Corruption)', 'Donations to Charity']]

# %%
Year_22.head()
# Out:
#    RANK  Year      Country          Region Happiness score  \
# 0     1  2022      Finland  Western Europe           7,821
# 1     2  2022      Denmark  Western Europe           7,636
# 2     3  2022      Iceland  Western Europe           7,557
# 3     4  2022  Switzerland  Western Europe           7,512
# 4     5  2022  Netherlands  Western Europe           7,415
#
#   Explained by: GDP per capita Family (Social Support)  \
# 0                        1,892                   1,258
# 1                        1,953                   1,243
# 2                        1,936                   1,320
# 3                        2,026                   1,226
# 4                        1,945                   1,206
#
#   Health (Life Expectancy) Freedom (Life Choices)  \
# 0                    0,775                  0,736
# 1                    0,777                  0,719
# 2                    0,803                  0,718
# 3                    0,822                  0,677
# ...

# %%
# rename columns
Year_22.rename(columns = {'Happiness score':'Happiness Score', 'RANK':'Rank', 'Explained by: Log GDP per capita':'Economy (GDP per Capita)'}, inplace = True)

# %%
Year_22.rename(columns = { 'Explained by: GDP per capita':'Economy (GDP per Capita)'}, inplace = True)

# %%
Year_22.head()
# Out:
#    Rank  Year      Country          Region Happiness Score  \
# 0     1  2022      Finland  Western Europe           7,821
# 1     2  2022      Denmark  Western Europe           7,636
# 2     3  2022      Iceland  Western Europe           7,557
# 3     4  2022  Switzerland  Western Europe           7,512
# 4     5  2022  Netherlands  Western Europe           7,415
#
#   Economy (GDP per Capita) Family (Social Support) Health (Life Expectancy)  \
# 0                    1,892                   1,258                    0,775
# 1                    1,953                   1,243                    0,777
# 2                    1,936                   1,320                    0,803
# 3                    2,026                   1,226                    0,822
# 4                    1,945                   1,206                    0,787
#
#   Freedom (Life Choices) Trust (Government Corruption) Donations to Charity
# 0                  0,736                         0,534                0,109
# ...

# %%
# checking the null data
Year_22.isnull().sum()
# Out:
# Rank                             0
# Year                             0
# Country                          0
# Region                           2
# Happiness Score                  1
# Economy (GDP per Capita)         1
# Family (Social Support)          1
# Health (Life Expectancy)         1
# Freedom (Life Choices)           1
# Trust (Government Corruption)    1
# Donations to Charity             1
# dtype: int64

# %%
print("Missing Data:\n", Year_22[Year_22.isnull().any(axis=1)])
# Out:
# Missing Data:
#       Rank  Year               Country Region Happiness Score  \
# 124   125  2022  Eswatini, Kingdom of    NaN           4,396
# 146   147  2022                    xx    NaN             NaN
#
#     Economy (GDP per Capita) Family (Social Support) Health (Life Expectancy)  \
# 124                    1,274                   0,786                    0,197
# 146                      NaN                     NaN                      NaN
#
#     Freedom (Life Choices) Trust (Government Corruption) Donations to Charity
# 124                  0,259                         0,154                0,038
# 146                    NaN                           NaN                  NaN

# %%
# Remove the missing data
Year_22 = Year_22.drop(124, axis=0)

# %%
Year_22 = Year_22.drop(146, axis=0)

# %%
print("Missing Data:\n", Year_22[Year_22.isnull().any(axis=1)])
# Out:
# Missing Data:
#  Empty DataFrame
# Columns: [Rank, Year, Country, Region, Happiness Score, Economy (GDP per Capita), Family (Social Support), Health (Life Expectancy), Freedom (Life Choices), Trust (Government Corruption), Donations to Charity]
# Index: []

# %%
# check for duplicates
Year_22[Year_22.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Rank, Year, Country, Region, Happiness Score, Economy (GDP per Capita), Family (Social Support), Health (Life Expectancy), Freedom (Life Choices), Trust (Government Corruption), Donations to Charity]
# Index: []

# %%
# drop the other missing values
Year_22_clean = Year_22.dropna()

# %%
Year_22_clean.shape
# Out:
# (145, 11)

# %%
Year_22_clean.describe()
# Out:
#              Rank    Year
# count  145.000000   145.0
# mean    73.144828  2022.0
# std     42.218180     0.0
# min      1.000000  2022.0
# 25%     37.000000  2022.0
# 50%     73.000000  2022.0
# 75%    109.000000  2022.0
# max    146.000000  2022.0

# %%
Year_22_clean.rename(columns = { ' Happiness Score':'Happiness Score'}, inplace = True)

# %%
Year_22_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 145 entries, 0 to 145
# Data columns (total 11 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Rank                           145 non-null    int64
#  1   Year                           145 non-null    int64
#  2   Country                        145 non-null    object
#  3   Region                         145 non-null    object
#  4   Happiness Score                145 non-null    object
#  5   Economy (GDP per Capita)       145 non-null    object
#  6   Family (Social Support)        145 non-null    object
#  7   Health (Life Expectancy)       145 non-null    object
#  8   Freedom (Life Choices)         145 non-null    object
#  9   Trust (Government Corruption)  145 non-null    object
#  10  Donations to Charity           145 non-null    object
# dtypes: int64(2), object(9)
# memory usage: 13.6+ KB

# %%
# Convert the values in the column 2 from integers to strings. & also replace the comma with a decimal point
Year_22_clean['Happiness Score'] = Year_22_clean['Happiness Score'].astype(str).str.replace(',', '.').astype(float)

# %%
Year_22_clean['Economy (GDP per Capita)'] = Year_22_clean['Economy (GDP per Capita)'].astype(str).str.replace(',', '.').astype(float)

# %%
Year_22_clean['Family (Social Support)'] = Year_22_clean['Family (Social Support)'].astype(str).str.replace(',', '.').astype(float)

# %%
Year_22_clean['Health (Life Expectancy)'] = Year_22_clean['Health (Life Expectancy)'].astype(str).str.replace(',', '.').astype(float)

# %%
Year_22_clean['Freedom (Life Choices)'] = Year_22_clean['Freedom (Life Choices)'].astype(str).str.replace(',', '.').astype(float)

# %%
Year_22_clean['Trust (Government Corruption)'] = Year_22_clean['Trust (Government Corruption)'].astype(str).str.replace(',', '.').astype(float)

# %%
Year_22_clean['Donations to Charity'] = Year_22_clean['Donations to Charity'].astype(str).str.replace(',', '.').astype(float)

# %%
Year_22_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 145 entries, 0 to 145
# Data columns (total 11 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Rank                           145 non-null    int64
#  1   Year                           145 non-null    int64
#  2   Country                        145 non-null    object
#  3   Region                         145 non-null    object
#  4   Happiness Score                145 non-null    float64
#  5   Economy (GDP per Capita)       145 non-null    float64
#  6   Family (Social Support)        145 non-null    float64
#  7   Health (Life Expectancy)       145 non-null    float64
#  8   Freedom (Life Choices)         145 non-null    float64
#  9   Trust (Government Corruption)  145 non-null    float64
#  10  Donations to Charity           145 non-null    float64
# dtypes: float64(7), int64(2), object(2)
# memory usage: 13.6+ KB

# %%
Year_22_clean.describe()
# Out:
#              Rank    Year  Happiness Score  Economy (GDP per Capita)  \
# count  145.000000   145.0       145.000000                145.000000
# mean    73.144828  2022.0         5.561559                  1.411386
# std     42.218180     0.0         1.086306                  0.422971
# min      1.000000  2022.0         2.404000                  0.000000
# 25%     37.000000  2022.0         4.891000                  1.094000
# 50%     73.000000  2022.0         5.578000                  1.452000
# 75%    109.000000  2022.0         6.309000                  1.793000
# max    146.000000  2022.0         7.821000                  2.209000
#
#        Family (Social Support)  Health (Life Expectancy)  \
# count               145.000000                145.000000
# mean                  0.906690                  0.588855
# std                   0.280914                  0.173929
# min                   0.000000                  0.000000
# ...

# %% [markdown]
#  9. Dataset of Year (2023)

# %%
Year_23 = pd.read_csv(r'C:\Users\swapn\World Happiness Report\02 Data\Original Data\2023.csv', index_col = False)

# %%
Year_23.shape
# Out:
# (137, 19)

# %%
Year_23.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 137 entries, 0 to 136
# Data columns (total 19 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Country name                                137 non-null    object
#  1   Ladder score                                137 non-null    float64
#  2   Standard error of ladder score              137 non-null    float64
#  3   upperwhisker                                137 non-null    float64
#  4   lowerwhisker                                137 non-null    float64
#  5   Logged GDP per capita                       137 non-null    float64
#  6   Social support                              137 non-null    float64
#  7   Healthy life expectancy                     136 non-null    float64
#  8   Freedom to make life choices                137 non-null    float64
# ...

# %%
Year_23.describe()
# Out:
#        Ladder score  Standard error of ladder score  upperwhisker  \
# count    137.000000                      137.000000    137.000000
# mean       5.539796                        0.064715      5.666526
# std        1.139929                        0.023031      1.117421
# min        1.859000                        0.029000      1.923000
# 25%        4.724000                        0.047000      4.980000
# 50%        5.684000                        0.060000      5.797000
# 75%        6.334000                        0.077000      6.441000
# max        7.804000                        0.147000      7.875000
#
#        lowerwhisker  Logged GDP per capita  Social support  \
# count    137.000000             137.000000      137.000000
# mean       5.412971               9.449796        0.799073
# std        1.163724               1.207302        0.129222
# min        1.795000               5.527000        0.341000
# 25%        4.496000               8.591000        0.722000
# ...

# %%
Year_23.head()
# Out:
#   Country name  Ladder score  Standard error of ladder score  upperwhisker  \
# 0      Finland         7.804                           0.036         7.875
# 1      Denmark         7.586                           0.041         7.667
# 2      Iceland         7.530                           0.049         7.625
# 3       Israel         7.473                           0.032         7.535
# 4  Netherlands         7.403                           0.029         7.460
#
#    lowerwhisker  Logged GDP per capita  Social support  \
# 0         7.733                 10.792           0.969
# 1         7.506                 10.962           0.954
# 2         7.434                 10.896           0.983
# 3         7.411                 10.639           0.943
# 4         7.346                 10.942           0.930
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                   71.150                         0.961      -0.019
# ...

# %%
# add new column
Year_23 ['Year'] = 2022

# %%
#remove unnecessary columns
Year_23.drop(['Standard error of ladder score', 'upperwhisker','lowerwhisker', 'Logged GDP per capita', 'Social support','Healthy life expectancy','Freedom to make life choices', 'Generosity', 'Perceptions of corruption','Ladder score in Dystopia'], axis=1, inplace=True)

# %%
# rename columns
Year_23.rename(columns = {'Country name':'Country', 'Ladder score':'Happiness Score', 'Explained by: Log GDP per capita':'Economy (GDP per Capita)', 'Explained by: Social support':'Family (Social Support)', 'Explained by: Healthy life expectancy': 'Health (Life Expectancy)', 'Explained by: Freedom to make life choices': 'Freedom (Life Choices)', 'Explained by: Generosity':'Donations to Charity', 'Explained by: Perceptions of corruption':'Trust (Government Corruption)'}, inplace = True)

# %%
Year_23.head()
# Out:
#        Country  Happiness Score  Economy (GDP per Capita)  \
# 0      Finland            7.804                     1.888
# 1      Denmark            7.586                     1.949
# 2      Iceland            7.530                     1.926
# 3       Israel            7.473                     1.833
# 4  Netherlands            7.403                     1.942
#
#    Family (Social Support)  Health (Life Expectancy)  Freedom (Life Choices)  \
# 0                    1.585                     0.535                   0.772
# 1                    1.548                     0.537                   0.734
# 2                    1.620                     0.559                   0.738
# 3                    1.521                     0.577                   0.569
# 4                    1.488                     0.545                   0.672
#
#    Donations to Charity  Trust (Government Corruption)  Dystopia + residual  \
# ...

# %%
Year_23.drop(['Dystopia + residual'], axis=1, inplace=True)

# %%
Year_23.head()
# Out:
#        Country  Happiness Score  Economy (GDP per Capita)  \
# 0      Finland            7.804                     1.888
# 1      Denmark            7.586                     1.949
# 2      Iceland            7.530                     1.926
# 3       Israel            7.473                     1.833
# 4  Netherlands            7.403                     1.942
#
#    Family (Social Support)  Health (Life Expectancy)  Freedom (Life Choices)  \
# 0                    1.585                     0.535                   0.772
# 1                    1.548                     0.537                   0.734
# 2                    1.620                     0.559                   0.738
# 3                    1.521                     0.577                   0.569
# 4                    1.488                     0.545                   0.672
#
#    Donations to Charity  Trust (Government Corruption)  Year
# 0                 0.126                          0.535  2022
# ...

# %%
# derive Region according to country names using loc()
Year_23.loc[Year_23['Country'].isin(['Australia', 'New Zealand']), 'Region'] = 'Australia and New Zealand'

# %%
Year_23.loc[Year_23['Country'].isin(['Albania', 'Armenia', 'Azerbaijan', 'Belarus', 'Bosnia and Herzegovina', 'Bulgaria', 'Croatia', 'Czech Republic', 'Estonia', 'Georgia', 'Hungary', 'Kazakhstan', 'Kosovo', 'Kyrgyzstan', 'Latvia', 'Lithuania', 'Macedonia', 'Moldova', 'Montenegro', 'Poland','Romania', 'Russia', 'Serbia', 'Slovakia', 'Slovenia', 'Tajikistan', 'Turkmenistan', 'Ukraine', 'Uzbekistan']), 'Region'] = 'Central and Eastern Europe'

# %%
Year_23.loc[Year_23['Country'].isin(['China', 'Hong Kong', 'Japan', 'Mongolia', 'South Korea', 'Taiwan']), 'Region'] = 'Eastern Asia'

# %%
Year_23.loc[Year_23['Country'].isin(['Argentina', 'Bolivia', 'Brazil', 'Belize', 'Venezuela', 'Chile', 'Colombia', 'Costa Rica', 'Dominican Republic','Ecuador', 'El Salvador', 'Guatemala', 'Haiti', 'Honduras', 'Jamaica', 'Mexico', 'Nicaragua', 'Panama', 'Paraguay', 'Peru', 'Suriname', 'Trinidad and Tobago', 'Uruguay', 'Uruguay']), 'Region'] = 'Latin America and Caribbean'

# %%
Year_23.loc[Year_23['Country'].isin(['Algeria', 'Bahrain','Egypt','Iran', 'Iraq', 'Israel', 'Jordan', 'Kuwait', 'Lebanon', 'Libya', 'Morocco', 'Oman', 'Palestinian Territories', 'Qatar', 'Saudi Arabia', 'Syria', 'Tunisia', 'Turkey', 'United Arab Emirates', 'Yemen']), 'Region'] = 'Middle East and Northern Africa'

# %%
Year_23.loc[Year_23['Country'].isin(['Canada', 'United States']), 'Region'] = 'North America'

# %%
Year_23.loc[Year_23['Country'].isin(['Cambodia', 'Indonesia', 'Laos', 'Malaysia', 'Myanmar', 'Philippines', 'Singapore','Thailand', 'Vietnam']), 'Region'] = 'Southeastern Asia'

# %%
Year_23.loc[Year_23['Country'].isin(['Afghanistan', 'Bangladesh', 'Bhutan', 'India', 'Nepal', 'Pakistan', 'Sri Lanka']), 'Region'] = 'Southern Asia'

# %%
Year_23.loc[Year_23['Country'].isin(['Angola', 'Benin', 'Botswana', 'Burkina Faso', 'Burundi', 'Cameroon', 'Central African Republic', 'Chad', 'Comoros', 'Congo (Brazzaville)', 'Congo (Kinshasa)', 'Djibouti', 'Ethiopia', 'Gabon', 'Ghana', 'Guinea', 'Ivory Coast', 'Kenya', 'Lesotho', 'Liberia', 'Madagascar', 'Malawi', 'Mali', 'Mauritania', 'Mauritius', 'Mozambique', 'Niger', 'Nigeria', 'Rwanda', 'Senegal', 'Sierra Leone', 'Gambia','Somaliland region', 'South Africa', 'Sudan', 'Swaziland', 'Tanzania', 'Togo', 'Uganda', 'Zambia', 'Zimbabwe', 'Somalia', 'Namibia']), 'Region'] = 'Sub-Saharan Africa'

# %%
Year_23.loc[Year_23['Country'].isin(['Austria', 'Belgium', 'Cyprus', 'Denmark', 'Finland', 'France', 'Germany', 'Greece', 'Iceland', 'Ireland', 'Italy', 'Luxembourg', 'Malta', 'Netherlands', 'North Cyprus', 'Norway', 'Portugal', 'Spain', 'Sweden', 'Switzerland', 'United Kingdom']), 'Region'] = 'Western Europe'

# %%
Year_23.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 137 entries, 0 to 136
# Data columns (total 10 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        137 non-null    object
#  1   Happiness Score                137 non-null    float64
#  2   Economy (GDP per Capita)       137 non-null    float64
#  3   Family (Social Support)        137 non-null    float64
#  4   Health (Life Expectancy)       136 non-null    float64
#  5   Freedom (Life Choices)         137 non-null    float64
#  6   Donations to Charity           137 non-null    float64
#  7   Trust (Government Corruption)  137 non-null    float64
#  8   Year                           137 non-null    int64
#  9   Region                         131 non-null    object
# dtypes: float64(7), int64(1), object(2)
# memory usage: 10.8+ KB

# %%
# Add the "Rank" column
Year_23['Rank'] = range(1, len(Year_23) + 1)

# %%
#change the order of columns
Year_23 = Year_23[['Rank', 'Year', 'Country', 'Region', 'Happiness Score', 'Economy (GDP per Capita)', 'Family (Social Support)', 'Health (Life Expectancy)', 'Freedom (Life Choices)', 'Trust (Government Corruption)', 'Donations to Charity']]

# %%
Year_23.info ()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 137 entries, 0 to 136
# Data columns (total 11 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Rank                           137 non-null    int64
#  1   Year                           137 non-null    int64
#  2   Country                        137 non-null    object
#  3   Region                         131 non-null    object
#  4   Happiness Score                137 non-null    float64
#  5   Economy (GDP per Capita)       137 non-null    float64
#  6   Family (Social Support)        137 non-null    float64
#  7   Health (Life Expectancy)       136 non-null    float64
#  8   Freedom (Life Choices)         137 non-null    float64
#  9   Trust (Government Corruption)  137 non-null    float64
#  10  Donations to Charity           137 non-null    float64
# dtypes: float64(7), int64(2), object(2)
# memory usage: 11.9+ KB

# %%
# checking the null data
Year_23.isnull().sum()
# Out:
# Rank                             0
# Year                             0
# Country                          0
# Region                           6
# Happiness Score                  0
# Economy (GDP per Capita)         0
# Family (Social Support)          0
# Health (Life Expectancy)         1
# Freedom (Life Choices)           0
# Trust (Government Corruption)    0
# Donations to Charity             0
# dtype: int64

# %%
print("Missing Data:\n", Year_23[Year_23.isnull().any(axis=1)])
# Out:
# Missing Data:
#       Rank  Year                    Country Region  Happiness Score  \
# 17     18  2022                    Czechia    NaN            6.845
# 26     27  2022   Taiwan Province of China    NaN            6.535
# 81     82  2022  Hong Kong S.A.R. of China    NaN            5.308
# 86     87  2022            North Macedonia    NaN            5.254
# 98     99  2022         State of Palestine    NaN            4.908
# 105   106  2022                    Turkiye    NaN            4.614
#
#      Economy (GDP per Capita)  Family (Social Support)  \
# 17                      1.823                    1.544
# 26                      1.890                    1.372
# 81                      1.951                    1.201
# 86                      1.498                    1.171
# 98                      1.144                    1.309
# 105                     1.714                    1.148
#
#      Health (Life Expectancy)  Freedom (Life Choices)  \
# ...

# %%
# Correcting country name 
Year_23['Country'] = Year_23['Country'].replace('Czechia', 'Czech Republic')
Year_23['Country'] = Year_23['Country'].replace('Taiwan Province of China', 'Taiwan')
# Correcting country name 
Year_23['Country'] = Year_23['Country'].replace('Hong Kong S.A.R. of China', 'Hong Kong')
Year_23['Country'] = Year_23['Country'].replace('North Macedonia', 'Macedonia')
Year_23['Country'] = Year_23['Country'].replace('State of Palestine', 'Palestinian Territories')

# %%
Year_23['Country'] = Year_23['Country'].replace('Turkiye', 'Turkey')

# %%
Year_23.isnull().sum()
# Out:
# Rank                             0
# Year                             0
# Country                          0
# Region                           6
# Happiness Score                  0
# Economy (GDP per Capita)         0
# Family (Social Support)          0
# Health (Life Expectancy)         1
# Freedom (Life Choices)           0
# Trust (Government Corruption)    0
# Donations to Charity             0
# dtype: int64

# %%
print("Missing Data:\n", Year_23[Year_23.isnull().any(axis=1)])
# Out:
# Missing Data:
#       Rank  Year                  Country Region  Happiness Score  \
# 17     18  2022           Czech Republic    NaN            6.845
# 26     27  2022                   Taiwan    NaN            6.535
# 81     82  2022                Hong Kong    NaN            5.308
# 86     87  2022                Macedonia    NaN            5.254
# 98     99  2022  Palestinian Territories    NaN            4.908
# 105   106  2022                   Turkey    NaN            4.614
#
#      Economy (GDP per Capita)  Family (Social Support)  \
# 17                      1.823                    1.544
# 26                      1.890                    1.372
# 81                      1.951                    1.201
# 86                      1.498                    1.171
# 98                      1.144                    1.309
# 105                     1.714                    1.148
#
#      Health (Life Expectancy)  Freedom (Life Choices)  \
# ...

# %%
# Remove the missing data
Year_23 = Year_23.drop(98, axis=0)

# %%
print("Missing Data:\n", Year_23[Year_23.isnull().any(axis=1)])
# Out:
# Missing Data:
#       Rank  Year         Country Region  Happiness Score  \
# 17     18  2022  Czech Republic    NaN            6.845
# 26     27  2022          Taiwan    NaN            6.535
# 81     82  2022       Hong Kong    NaN            5.308
# 86     87  2022       Macedonia    NaN            5.254
# 105   106  2022          Turkey    NaN            4.614
#
#      Economy (GDP per Capita)  Family (Social Support)  \
# 17                      1.823                    1.544
# 26                      1.890                    1.372
# 81                      1.951                    1.201
# 86                      1.498                    1.171
# 105                     1.714                    1.148
#
#      Health (Life Expectancy)  Freedom (Life Choices)  \
# 17                      0.477                   0.693
# 26                      0.492                   0.562
# 81                      0.702                   0.407
# 86                      0.408                   0.515
# ...

# %%
Year_23.isnull().sum()
# Out:
# Rank                             0
# Year                             0
# Country                          0
# Region                           5
# Happiness Score                  0
# Economy (GDP per Capita)         0
# Family (Social Support)          0
# Health (Life Expectancy)         0
# Freedom (Life Choices)           0
# Trust (Government Corruption)    0
# Donations to Charity             0
# dtype: int64

# %%
# check for duplicates
Year_23[Year_23.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Rank, Year, Country, Region, Happiness Score, Economy (GDP per Capita), Family (Social Support), Health (Life Expectancy), Freedom (Life Choices), Trust (Government Corruption), Donations to Charity]
# Index: []

# %%
# drop the other missing values
Year_23_clean = Year_23.dropna()

# %%
Year_23_clean.isnull().sum()
# Out:
# Rank                             0
# Year                             0
# Country                          0
# Region                           0
# Happiness Score                  0
# Economy (GDP per Capita)         0
# Family (Social Support)          0
# Health (Life Expectancy)         0
# Freedom (Life Choices)           0
# Trust (Government Corruption)    0
# Donations to Charity             0
# dtype: int64

# %%
Year_23_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 131 entries, 0 to 136
# Data columns (total 11 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Rank                           131 non-null    int64
#  1   Year                           131 non-null    int64
#  2   Country                        131 non-null    object
#  3   Region                         131 non-null    object
#  4   Happiness Score                131 non-null    float64
#  5   Economy (GDP per Capita)       131 non-null    float64
#  6   Family (Social Support)        131 non-null    float64
#  7   Health (Life Expectancy)       131 non-null    float64
#  8   Freedom (Life Choices)         131 non-null    float64
#  9   Trust (Government Corruption)  131 non-null    float64
#  10  Donations to Charity           131 non-null    float64
# dtypes: float64(7), int64(2), object(2)
# memory usage: 12.3+ KB

# %%
Year_23_clean.describe()
# Out:
#              Rank    Year  Happiness Score  Economy (GDP per Capita)  \
# count  131.000000   131.0       131.000000                131.000000
# mean    68.961832  2022.0         5.538076                  1.394939
# std     39.917300     0.0         1.152380                  0.435016
# min      1.000000  2022.0         1.859000                  0.000000
# 25%     35.500000  2022.0         4.681000                  1.087500
# 50%     68.000000  2022.0         5.703000                  1.428000
# 75%    103.500000  2022.0         6.332000                  1.762500
# max    137.000000  2022.0         7.804000                  2.200000
#
#        Family (Social Support)  Health (Life Expectancy)  \
# count               131.000000                131.000000
# mean                  1.150046                  0.360718
# std                   0.331135                  0.155856
# min                   0.000000                  0.000000
# ...

# %%
Year_23_clean.shape
# Out:
# (131, 11)

# %%
Year_23_clean.columns
# Out:
# Index(['Rank', 'Year', 'Country', 'Region', 'Happiness Score',
#        'Economy (GDP per Capita)', 'Family (Social Support)',
#        'Health (Life Expectancy)', 'Freedom (Life Choices)',
#        'Trust (Government Corruption)', 'Donations to Charity'],
#       dtype='object')

# %%
Year_22_clean.columns
# Out:
# Index(['Rank', 'Year', 'Country', 'Region', 'Happiness Score',
#        'Economy (GDP per Capita)', 'Family (Social Support)',
#        'Health (Life Expectancy)', 'Freedom (Life Choices)',
#        'Trust (Government Corruption)', 'Donations to Charity'],
#       dtype='object')

# %%
Year_21_clean.columns
# Out:
# Index(['Rank', 'Year', 'Country', 'Region', 'Happiness Score',
#        'Economy (GDP per Capita)', 'Family (Social Support)',
#        'Health (Life Expectancy)', 'Freedom (Life Choices)',
#        'Trust (Government Corruption)', 'Donations to Charity'],
#       dtype='object')

# %%
Year_20_clean.columns
# Out:
# Index(['Rank', 'Year', 'Country', 'Region', 'Happiness Score',
#        'Economy (GDP per Capita)', 'Family (Social Support)',
#        'Health (Life Expectancy)', 'Freedom (Life Choices)',
#        'Trust (Government Corruption)', 'Donations to Charity'],
#       dtype='object')

# %%
Year_19_clean.columns
# Out:
# Index(['Rank', 'Year', 'Country', 'Region', 'Happiness Score',
#        'Economy (GDP per Capita)', 'Family (Social Support)',
#        'Health (Life Expectancy)', 'Freedom (Life Choices)',
#        'Trust (Government Corruption)', 'Donations to Charity'],
#       dtype='object')

# %%
Year_18_clean.columns
# Out:
# Index(['Rank', 'Year', 'Country', 'Region', 'Happiness Score',
#        'Economy (GDP per Capita)', 'Family (Social Support)',
#        'Health (Life Expectancy)', 'Freedom (Life Choices)',
#        'Trust (Government Corruption)', 'Donations to Charity'],
#       dtype='object')

# %%
Year_17_clean.columns
# Out:
# Index(['Rank', 'Year', 'Country', 'Region', 'Happiness Score',
#        'Economy (GDP per Capita)', 'Family (Social Support)',
#        'Health (Life Expectancy)', 'Freedom (Life Choices)',
#        'Trust (Government Corruption)', 'Donations to Charity'],
#       dtype='object')

# %%
Year_16_clean.columns
# Out:
# Index(['Rank', 'Year', 'Country', 'Region', 'Happiness Score',
#        'Economy (GDP per Capita)', 'Family (Social Support)',
#        'Health (Life Expectancy)', 'Freedom (Life Choices)',
#        'Trust (Government Corruption)', 'Donations to Charity'],
#       dtype='object')

# %%
Year_15_clean.columns
# Out:
# Index(['Rank', 'Year', 'Country', 'Region', 'Happiness Score',
#        'Economy (GDP per Capita)', 'Family (Social Support)',
#        'Health (Life Expectancy)', 'Freedom (Life Choices)',
#        'Trust (Government Corruption)', 'Donations to Charity'],
#       dtype='object')

# %% [markdown]
# # Export clean data frames (2015 to 2023) to preapared data

# %%
Year_15_clean.to_csv(os.path.join(path, '02 Data', 'Prepared Data', 'Year_15_clean.csv'))

# %%
Year_16_clean.to_csv(os.path.join(path, '02 Data', 'Prepared Data', 'Year_16_clean.csv'))

# %%
Year_17_clean.to_csv(os.path.join(path, '02 Data', 'Prepared Data', 'Year_17_clean.csv'))

# %%
Year_18_clean.to_csv(os.path.join(path, '02 Data', 'Prepared Data', 'Year_18_clean.csv'))

# %%
Year_19_clean.to_csv(os.path.join(path, '02 Data', 'Prepared Data', 'Year_19_clean.csv'))

# %%
Year_20_clean.to_csv(os.path.join(path, '02 Data', 'Prepared Data', 'Year_20_clean.csv'))

# %%
Year_21_clean.to_csv(os.path.join(path, '02 Data', 'Prepared Data', 'Year_21_clean.csv'))

# %%
Year_22_clean.to_csv(os.path.join(path, '02 Data', 'Prepared Data', 'Year_22_clean.csv'))

# %%
Year_23_clean.to_csv(os.path.join(path, '02 Data', 'Prepared Data', 'Year_23_clean.csv'))

# %%
Year_23_clean.

# %% [markdown]
# # Merge the Dataframes

# %%
df_years = (Year_15_clean, Year_16_clean, Year_17_clean, Year_18_clean, Year_19_clean, Year_20_clean, Year_21_clean, Year_22_clean, Year_23_clean)

# %%
df_merged = pd.concat(df_years)

# %%
df_merged.head()
# Out:
#    Rank  Year      Country          Region  Happiness Score  \
# 0     1  2015  Switzerland  Western Europe            7.587
# 1     2  2015      Iceland  Western Europe            7.561
# 2     3  2015      Denmark  Western Europe            7.527
# 3     4  2015       Norway  Western Europe            7.522
# 4     5  2015       Canada   North America            7.427
#
#    Economy (GDP per Capita)  Family (Social Support)  \
# 0                   1.39651                  1.34951
# 1                   1.30232                  1.40223
# 2                   1.32548                  1.36058
# 3                   1.45900                  1.33095
# 4                   1.32629                  1.32261
#
#    Health (Life Expectancy)  Freedom (Life Choices)  \
# 0                   0.94143                 0.66557
# 1                   0.94784                 0.62877
# 2                   0.87464                 0.64938
# 3                   0.88521                 0.66973
# ...

# %% [markdown]
# # Exporting merge dataset in prepared data

# %%
#Exporting merge dataset in prepared data  
df_merged.to_csv(os.path.join(path, '02 Data', 'Prepared Data', 'merged_dataset_2015to2022.csv'), index=False)

# %%
df = df_merged

# %%
df.shape
# Out:
# (1359, 11)

# %%
#Checking for nulls 
df.isnull().sum()
# Out:
# Rank                             0
# Year                             0
# Country                          0
# Region                           0
# Happiness Score                  0
# Economy (GDP per Capita)         0
# Family (Social Support)          0
# Health (Life Expectancy)         0
# Freedom (Life Choices)           0
# Trust (Government Corruption)    0
# Donations to Charity             0
# dtype: int64

# %%
#Checking for duplicates
df_dups = df[df.duplicated()]
df_dups
# Out:
# Empty DataFrame
# Columns: [Rank, Year, Country, Region, Happiness Score, Economy (GDP per Capita), Family (Social Support), Health (Life Expectancy), Freedom (Life Choices), Trust (Government Corruption), Donations to Charity]
# Index: []

# %% [markdown]
# # Descriptive Statistics

# %%
#Descriptive Statistics 
df.describe()
# Out:
#               Rank         Year  Happiness Score  Economy (GDP per Capita)  \
# count  1359.000000  1359.000000      1359.000000               1359.000000
# mean     76.613687  2018.787344         5.440273                  1.015570
# std      44.110370     2.410022         1.118877                  0.451591
# min       1.000000  2015.000000         1.859000                  0.000000
# 25%      39.000000  2017.000000         4.594000                  0.694145
# 50%      76.000000  2019.000000         5.456200                  1.038000
# 75%     114.500000  2021.000000         6.254000                  1.335144
# max     158.000000  2022.000000         7.842000                  2.209000
#
#        Family (Social Support)  Health (Life Expectancy)  \
# count              1359.000000               1359.000000
# mean                  1.044639                  0.584540
# std                   0.331453                  0.245394
# min                   0.000000                  0.000000
# ...

# %%
#Checking for mixed-type columns 
df.dtypes
# Out:
# Rank                               int64
# Year                               int64
# Country                           object
# Region                            object
# Happiness Score                  float64
# Economy (GDP per Capita)         float64
# Family (Social Support)          float64
# Health (Life Expectancy)         float64
# Freedom (Life Choices)           float64
# Trust (Government Corruption)    float64
# Donations to Charity             float64
# dtype: object

# %%
# Exporting Cleaned Dataframe
df.to_csv(os.path.join(path, '02 Data', 'Prepared Data', 'cleaned_merged_dataset_2015to2022.csv'), index=False)
