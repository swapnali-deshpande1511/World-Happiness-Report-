# %% [markdown]
# # Exercise 6.2 Exporatory Analysis

# %%
# 1. Importing Libraries and Data

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
import os

# %% [markdown]
# # 2. Importing dataframe

# %%
path = r'C:\Users\swapn\World Happiness Report'

# %%
df = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'cleaned_merged_dataset_2015to2022.csv'), index_col = False)

# %%
# Checking shape of dataframe 
df.shape
# Out:
# (1359, 11)

# %%
df
# Out:
#       Rank  Year           Country                           Region  \
# 0        1  2015       Switzerland                   Western Europe
# 1        2  2015           Iceland                   Western Europe
# 2        3  2015           Denmark                   Western Europe
# 3        4  2015            Norway                   Western Europe
# 4        5  2015            Canada                    North America
# ...    ...   ...               ...                              ...
# 1354   133  2022  Congo (Kinshasa)               Sub-Saharan Africa
# 1355   134  2022          Zimbabwe               Sub-Saharan Africa
# 1356   135  2022      Sierra Leone               Sub-Saharan Africa
# 1357   136  2022           Lebanon  Middle East and Northern Africa
# 1358   137  2022       Afghanistan                    Southern Asia
#
#       Happiness Score  Economy (GDP per Capita)  Family (Social Support)  \
# 0               7.587                   1.39651                  1.34951
# ...

# %% [markdown]
# # 3. Creating a Correlation Matrix Heatmap

# %%
# Creating a correlation matrix using pandas
df_sub = df[[ 'Rank', 'Year','Happiness Score', 'Economy (GDP per Capita)', 'Family (Social Support)', 'Health (Life Expectancy)', 'Freedom (Life Choices)',
       'Trust (Government Corruption)', 'Donations to Charity']]

# %%
# Create a correlation matrix using pandas
df_sub.corr()
# Out:
#                                    Rank      Year  Happiness Score  \
# Rank                           1.000000 -0.059943        -0.986493
# Year                          -0.059943  1.000000         0.062832
# Happiness Score               -0.986493  0.062832         1.000000
# Economy (GDP per Capita)      -0.740262  0.306847         0.727349
# Family (Social Support)       -0.647262  0.003974         0.649448
# Health (Life Expectancy)      -0.682091 -0.120194         0.683721
# Freedom (Life Choices)        -0.556609  0.285784         0.569737
# Trust (Government Corruption) -0.395565  0.033654         0.417063
# Donations to Charity          -0.061916 -0.287358         0.082014
#
#                                Economy (GDP per Capita)  \
# Rank                                          -0.740262
# Year                                           0.306847
# Happiness Score                                0.727349
# Economy (GDP per Capita)                       1.000000
# ...

# %% [markdown]
# # 3.1. Create a correlation heatmap using matplotlib

# %%
plt.matshow(df_sub.corr())
plt.show()

# %%
# Adding labels, a legend, and changing the size of the heatmap
f = plt.figure(figsize=(10, 10)) # figure size 
plt.matshow(df_sub.corr(), fignum=f.number) # type of plot
plt.xticks(range(df_sub.shape[1]), df_sub.columns, fontsize=10, rotation=80) # x axis labels
plt.yticks(range(df_sub.shape[1]), df_sub.columns, fontsize=10) # y axis labels
cb = plt.colorbar() # add a colour legend (called colorbar)
cb.ax.tick_params(labelsize=11) # add font size
plt.title('Correlation Matrix', fontsize=14) # add title
# Out:
# Text(0.5, 1.0, 'Correlation Matrix')

# %% [markdown]
# # 3.2. Create a correlation heatmap using seaborn

# %%
df_sub.columns
# Out:
# Index(['Rank', 'Year', 'Happiness Score', 'Economy (GDP per Capita)',
#        'Family (Social Support)', 'Health (Life Expectancy)',
#        'Freedom (Life Choices)', 'Trust (Government Corruption)',
#        'Donations to Charity'],
#       dtype='object')

# %%
# Creating a subset excluding the "Country Rank", "Country", Year" and "Region" columns

sub = df_sub[['Happiness Score', 'Economy (GDP per Capita)', 'Family (Social Support)', 'Health (Life Expectancy)', 'Freedom (Life Choices)',
       'Trust (Government Corruption)', 'Donations to Charity']]

# %%
# Creating a subplot with matplotlib
f,ax = plt.subplots(figsize=(10,10))

# Create the correlation heatmap in seaborn by applying a heatmap onto the correlation matrix and the subplots defined above.
corr = sns.heatmap(sub.corr(), annot = True, ax = ax)
# The `annot` argument allows the plot to place the correlation coefficients onto the heatmap.
plt.title('Correlation Heatmap', fontsize=14) 
# to add title
# Out:
# Text(0.5, 1.0, 'Correlation Heatmap')

# %%
# 3.3. Discuss what the coefficients in the plot mean in terms of the relationships between the variables

# %%
# In this analysis happiness Score is independent variable and the other variables are dependent variables. Relationships between the variables are as follows:
# With “Happiness Score”: At 0.57 we see a medium-strong relationship with "Freedom (Life Choices)". This could be interpreted as follows: the more freedom a population is, the happier they will be.
# With "Economy (GDP per Capita)": At 0.74 we see a strong relationship with "Health (Life Expectancy)". This could be interpreted as follows: As life expectancy within a nation continues to rise, so will its economy.
# With "Family (Social Support)": At 0.62 we see a strong relationship with Health (Life Expectancy). This could be interpreted as follows: As the stronger relationship a population has with their family, we can expect to see an increase in life expectancy of individuals.	
# With "Freedom "(Life Choices)": At 0.19 we see a weak relationship between Generosity (Donations to Charity). This could be interpreted: As the less a population has the freedom to make choices, the less they will be generous in donations to charities.
# With "Trust (Government Corruption)": At 0.28 we see a weak relationship between Health (Life Expectancy). This could be interpreted: As a population has less trust in its government then life expectancy will also decrease.

# %% [markdown]
# # 4. Creating a Scatterplot

# %%
# Create a scatterplot for the "Happiness score" and "Economy (GDP per Capita)" columns in seaborn
sns.lmplot(x = 'Happiness Score', y = 'Economy (GDP per Capita)', data = df)

# %%
# Create a scatterplot for the "Happiness score" and "Family (Social Support)" columns in seaborn
sns.lmplot(x = 'Happiness Score', y = 'Family (Social Support)', data = df)

# %%
# Create a scatterplot for the "Happiness score" and "Health (Life Expectancy)" columns in seaborn
sns.lmplot(x = 'Happiness Score', y = 'Health (Life Expectancy)', data = df)

# %%
# Create a scatterplot for the "Happiness score" and "Trust (Government Corruption)" columns in seaborn
sns.lmplot(x = 'Happiness Score', y = 'Trust (Government Corruption)', data = df)

# %%
# Create a scatterplot for the "Happiness score" and "Generosity (Donations to Charity)" columns in seaborn
sns.lmplot(x = 'Happiness Score', y = 'Donations to Charity', data = df)

# %%
# There is a strong positive relationship between Happiness Score and variables like Economy (GDP per Capita), Family (Social Support), Health (Life Expectancy). The Happiness Score has weak relationship with the variables Trust (Government Corruption) and Generosity (Donations to Charity).

# %% [markdown]
# # 5. Create a Pair Plot

# %% [markdown]
# # 5.1. Create a Pair Plot

# %%
# Creating a subplot with strictly these variables for the pair plot 
sub_2 = sub[['Happiness Score', 'Economy (GDP per Capita)', 'Family (Social Support)', 'Health (Life Expectancy)', 'Freedom (Life Choices)',
       'Trust (Government Corruption)', 'Donations to Charity']]

# %%
# Creating a pair plot 

g = sns.pairplot(sub_2)

# %% [markdown]
# # 5.2. Comment on the distribution of the variables and mark variables you’d like to explore further with an explanation of why.

# %%
# I would like to explore following variables further:
# Happiness Score vs. Economy (GDP per Capita), Happiness Score vs. Family (Social Support), Happiness Score vs. Health (Life Expectancy), Happiness Score vs. Freedom (Life Choices), Happiness Score vs Trust (Government Corruption), Happiness Score vs Generosity (Donations to Charity)
# Economy (GDP per Capita) vs. Health (Life Expectancy), Economy (GDP per Capita) vs. Trust (Government Corruption), Economy (GDP per Capita) vs. Generosity (Donations to Charity)
# Family (Social Support) vs. Trust (Government Corruption), Family (Social Support) vs. Generosity (Donations to Charity)
# Health (Life Expectancy) vs. Economy (GDP per Capita), Health (Life Expectancy) vs. Family (Social Support), Health (Life Expectancy) vs. Trust (Government Corruption), Health (Life Expectancy) vs. Generosity (Donations to Charity)
# Freedom (Life Choices) vs. Trust (Government Corruption), Freedom (Life Choices) vs. Generosity (Donations to Charity)
# Trust (Government Corruption) vs. Economy (GDP per Capita), Trust (Government Corruption) vs. Family (Social Support), Trust (Government Corruption) vs. Health (Life Expectancy), Trust (Government Corruption) vs. Freedom (Life Choices), Trust (Government Corruption) vs. Generosity (Donations to Charity)

# %% [markdown]
# # 6. Creating a Categorical Plot

# %%
# Creating a Categorical plot 
sns.histplot(df['Happiness Score'], bins = 20, kde = True)
# Out:
# <Axes: xlabel='Happiness Score', ylabel='Count'>

# %%
# Creating a Happiness flag for Countries
df.loc[df['Happiness Score'] < 4, 'Happiness Status'] = 'Unhappy Country'
df.loc[(df['Happiness Score'] >= 4) & (df['Happiness Score'] < 6), 'Happiness Status'] = 'Somewhat Happy Country'
df.loc[df['Happiness Score'] >= 6, 'Happiness Status'] = 'Happy Country'

# %%
# Checking creation of Exclusion flag 
df['Happiness Status'].value_counts(dropna = False)
# Out:
# Happiness Status
# Somewhat Happy Country    767
# Happy Country             448
# Unhappy Country           144
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['Rank', 'Year', 'Country', 'Region', 'Happiness Score',
#        'Economy (GDP per Capita)', 'Family (Social Support)',
#        'Health (Life Expectancy)', 'Freedom (Life Choices)',
#        'Trust (Government Corruption)', 'Donations to Charity',
#        'Happiness Status'],
#       dtype='object')

# %%
# Creating a categorical plot in seaborn using the Happiness Status created above
sns.set(style="ticks")
g= sns.catplot(x="Country", y="Happiness Score", hue="Happiness Status", data=df)

# %%
# Majority of countries are in Somewhat happy country status as per this categorial plot and it has happiness score between 4 to 6. Then comes the happy country which has happiness score between 6 to 10. Very less countries are in Unhappy country status and it has happiness score between 0 to 4.

# %%
# 7. Revisit the questions you generated in the previous task and write answers to those you can based on the exploration you’ve conducted so far. Add any new questions that may have arisen based on the early findings in your visual exploration.
# Which factors affects the most on happiness score? 
# This exploratory analysis shows that the factors contribute most to a country’s happiness are Economy (GDP per Capita), Family (Social Support), Health (Life Expectancy) and Freedom (Life Choices).

# %%
# 8. Define any hypotheses that you can at this point. You’ll be testing these later on.
# If the country’s scores in Economy (GDP per Capita), Family (Social Support) and Health (Life Expectancy) are high, happiness Scores of this country will be high.

# %%
df.to_csv(os.path.join(path, '02 Data', 'Prepared Data', 'exploring relationship_dataset.csv'), index=False)

# %% [markdown]
# # 9. Exporting Dataframe
